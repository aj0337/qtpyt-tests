# %%
import utils.local_plotter as local_pl

# %%
# Run the function to process and plot HOMO-LUMO values for all folders
data_folder = "output/compute_run/toy_model1"  # Specify your data folder
local_pl.process_and_plot_homo_lumo(data_folder)

# %%
data_folder = "output/compute_run/toy_model1"  # Specify your data folder
local_pl.plot_selected_quantities(data_folder=data_folder, quantities=["bath_couplings"], selected_impurities=[0])#,iteration_list=[0, 10])
# Out:
# Processing folder: nbaths_4_U_4.0 (nbaths=4, U=4.0)
# Processing folder: nbaths_8_U_6.0 (nbaths=8, U=6.0)
# Processing folder: nbaths_4_U_6.0 (nbaths=4, U=6.0)
# Processing folder: nbaths_8_U_5.0 (nbaths=8, U=5.0)
# Processing folder: nbaths_8_U_4.0 (nbaths=8, U=4.0)
# Processing folder: nbaths_4_U_5.0 (nbaths=4, U=5.0)

# %%
data_folder = "output/compute_run/toy_model1"  # Specify your data folder
local_pl.plot_selected_quantities(data_folder=data_folder, quantities=["dmft_transmission","dft_transmission"])
