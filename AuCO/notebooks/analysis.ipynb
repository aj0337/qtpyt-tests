# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
output_folder = "../output/no_lowdin/"
E,dos = np.load(f"{output_folder}/ET.npy")
plt.plot(E,dos)
plt.xlabel("Energy")
plt.ylabel("Transmission")
# Out:
# Text(0, 0.5, 'Transmission')

# %%
E,dos = np.load(f"{output_folder}/Edos.npy")
plt.plot(E,dos)
plt.xlabel("Energy")
plt.ylabel("DOS")
# Out:
# Text(0, 0.5, 'DOS')
