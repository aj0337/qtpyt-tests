# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,4))

dos_BDA = np.load("pdos_eta_0.025.npy")
dos_BDA_los = np.load("../BDA_active/pdos_eta_0.025.npy")
# dos1_BDA = np.load("pdos_eta_0.1.npy")
energies = np.load("energies.npy")
plt.plot(energies,dos_BDA,label="1,3 BDA eta 0.025 no localization")
plt.plot(energies,dos_BDA_los,label="1,3 BDA eta 0.025 with localized orbitals")
# plt.plot(energies,dos1_BDA,label="1,3 BDA smearing 0.1")
plt.legend()
plt.ylim(0,2.5)
plt.xlim(-2,2)
plt.xlabel(r"E-$E_{F}$(eV)")
plt.ylabel("DOS")
# Out:
# Text(0, 0.5, 'DOS')
