# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ### leads treated like principle layer

# %%
E,T = np.load("lcao/ET_eta0.001.npy")
plt.plot(E,T)
plt.plot(ref[:,0],ref[:,1],label="Reference")
plt.yscale("log")
plt.ylim(5e-5,1.5)
plt.xlim(-3,3)
plt.ylabel("T(E)")
plt.xlabel(r"$E-E_{f} (eV)$")
# Out:
# Text(0.5, 0, '$E-E_{f} (eV)$')

# %% [markdown]
# ### leads treated like bulk

# %%
E,T = np.load("lcao_bulk_leads/ET_eta0.001.npy")
ref = np.loadtxt("Ref_trans/ET_hs.dat")
plt.plot(E,T)
plt.plot(ref[:,0],ref[:,1],label="Reference")
plt.yscale("log")
plt.ylim(1e-5,1.5)
plt.xlim(-3,3)
plt.ylabel("T(E)")
plt.xlabel(r"$E-E_{f} (eV)$")
plt.legend()

# %%
from pathlib import Path

import numpy as np
from qtpyt.surface.tools import prepare_leads_matrices

# %%
GPWDEVICEDIR = '../dft/device/'
GPWLEADSDIR = '../dft/leads_bulk/'

leads_path = Path(GPWLEADSDIR)
device_path = Path(GPWDEVICEDIR)

# %%
H_leads_dft, S_leads_dft = np.load(leads_path / 'hs_leads_k.npy')


H_device_dft, S_device_dft = np.load(device_path/'hs_cc_k.npy')
kpts_t, h_leads_kii, s_leads_kii, h_leads_kij, s_leads_kij = prepare_leads_matrices(
    H_leads_dft, S_leads_dft, (5, 1, 1), align=(0, H_device_dft[0, 0, 0]))

# %%
kpts_t.shape
# Out:
# (1, 3)

# %%
H_device_dft.shape
# Out:
# (1, 1368, 1368)

# %%
H_leads_dft.shape
# Out:
# (3, 432, 432)

# %%
h_leads_kii.shape
# Out:
# (1, 432, 432)
