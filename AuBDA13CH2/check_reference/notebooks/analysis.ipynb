# %%
import os
import numpy as np
import matplotlib.pyplot as plt
new_path = '/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/check_reference'
os.chdir(new_path)

# %%
E,T_dft = np.load("./output/lowdin/ET_dft.npy")
plt.plot(E,T_dft,label='DFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-5)
# Out:
# (1e-05, 1.3374398490778932)

# %%
E1,T1 = np.load("./output/lowdin/beta_38.68/ed_transmission_fixed_U.npy")
E2,T2 = np.load("./output/lowdin/ed_transmission_test.npy")
E3,T3 = np.load("../reference/ET_ed.npy")
E4,T4 = np.load("./output/lowdin/beta_38.68/ed_transmission_test.npy")
plt.plot(E3,T3,label='Published')
plt.plot(E2,T2,'.',label='Computed using reference self-energy data with Uii')
plt.plot(E1,T1,'.',label='Computed using reference self-energy data with possibly fixed U')
plt.plot(E4,T4,label='Computed using my self-energy data with Uii')
# plt.plot(E,T_dft,label='dft')
plt.ylabel('Transmission')
plt.xlabel('Energy (eV)')
plt.yscale('log')
plt.legend()
plt.xlim(-1,1)
plt.ylim(bottom=1e-5)
# Out:
# (1e-05, 3.6574740967893877)
