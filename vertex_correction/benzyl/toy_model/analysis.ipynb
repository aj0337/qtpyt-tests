# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
energies = np.load("output/energies.npy")
H = np.load("output/hamiltonian.npy")
gamma_L = np.load("output/gamma_L.npy")
gamma_R = np.load("output/gamma_R.npy")
sigma_D = np.load("output/ed/self_energy.npy")

# %%
print("Hamiltonian:\n", H)
eigvals, eigvecs = np.linalg.eig(H)
print("Eigenvalues:", eigvals)
# Out:
# Hamiltonian:
#  [[-1.5   0.1   0.5 ]
#  [ 0.1   0.25  0.1 ]
#  [ 0.5   0.1   1.5 ]]
# Eigenvalues: [-1.58487383  1.59097012  0.24390371]

# %%
from pathlib import Path

g_path = Path("output") / "dft" / "G_retarded.npz"
if not g_path.exists():
    print(f"Missing {g_path}. Run the workflow with METHOD='dft' to generate it.")
else:
    data = np.load(g_path)
    E_G = data["energies"]
    G = data["G"]  # shape: (nE, n, n) complex
    idx_l, idx_r = 0, 2
    G_lr = G[:, idx_l, idx_r]

    plt.figure(figsize=(8, 6))
    plt.plot(E_G, G_lr.real, label="Real part")
    plt.plot(E_G, G_lr.imag, label="Imaginary part")
    plt.xlabel("Energy (eV)")
    plt.ylabel("G(l,r)")
    plt.title("Retarded Green's Function element")
    plt.xlim(-0.5, 1.0)
    plt.legend()
    plt.grid()
    plt.show()

# %%
energies = np.load("output/energies.npy")
se = np.load("output/ed/self_energy.npy")
se_trace = np.trace(se, axis1=1, axis2=2)
plt.figure(figsize=(8, 6))
plt.plot(energies,se_trace.real, label="Real part")
plt.plot(energies,se_trace.imag, label="Imaginary part")
plt.xlabel("Energy (eV)")
plt.ylabel("Trace of Self-Energy")
plt.title("ED Self-Energy")
plt.legend()
plt.grid()
# plt.xlim(-1.0, 1.23)
plt.show()

# %%
from pathlib import Path

def load_ET(path):
    """Load ET.npy from a scheme folder.

    Supports two formats:
      - 2 rows: (E, T_total)
      - 4 rows: (E, T_elastic, T_inelastic, T_total)
    """
    p = Path(path)
    arr = np.load(p)
    if arr.shape[0] == 2:
        E, Ttot = arr
        return E, None, None, Ttot
    if arr.shape[0] == 4:
        E, Tel, Tin, Ttot = arr
        return E, Tel, Tin, Ttot
    raise ValueError(f"Unexpected ET.npy shape {arr.shape} in {p}")


E_none, _, _, T_none = load_ET("output/ed/none/ET.npy")

# For DFT, ET.npy lives under output/dft/<scheme>/ET.npy
# (Pick the scheme folder you ran the DFT workflow with.)
DFT_SCHEME = "none"
E_dft, _, _, T_dft = load_ET(Path("output") / "dft" / DFT_SCHEME / "ET.npy")

plt.figure(figsize=(8, 6))
plt.plot(E_none, T_none, label="Transmission (ED, scheme=none, total)")
plt.plot(E_dft, T_dft, label=f"Transmission (DFT, scheme={DFT_SCHEME}, total)")
plt.xlabel("Energy (eV)")
plt.ylabel("Transmission")
plt.title("Transmission vs Energy")
plt.legend()
plt.grid()
plt.ylim(1e-8, 1.0)
plt.yscale("log")

# %%
E, Tel, Tin_ferretti, T_ferretti = np.load("output/ed/ferretti/ET.npy")
plt.figure(figsize=(8, 6))
plt.plot(E, T_ferretti,  label="Transmission (ED, total)")
plt.plot(E, Tel,label="Transmission (ED, elastic)")
plt.plot(E, Tin_ferretti,  label="Transmission (ED, inelastic)")
plt.xlabel("Energy (eV)")
plt.ylabel("Transmission")
plt.title("Transmission vs Energy")
plt.legend()
plt.grid()
# plt.ylim(1e-8, 1.0)
plt.yscale("log")

# %%
E, Tel, Tin_brazilian, T_brazilian = np.load("output/ed/brazilian/ET.npy")
plt.figure(figsize=(8, 6))
plt.plot(E, T_brazilian, label="Transmission (ED, total)")
plt.plot(E, Tel, label="Transmission (ED, elastic)")
plt.plot(E, Tin_brazilian, label="Transmission (ED, inelastic)")
plt.xlabel("Energy (eV)")
plt.ylabel("Transmission")
plt.title("Transmission vs Energy")
plt.legend()
plt.grid()
# plt.ylim(1e-8, 1.0)
# plt.xlim(-1,1)
plt.yscale("log")

# %%
from pathlib import Path

def load_lambda_trace(folder):
    """Load energies and trace(Lambda) from a workflow output scheme folder."""
    p = Path(folder) / "vertex_correction.npz"
    if not p.exists():
        print(f"Missing vertex correction file (this is expected for scheme='none'): {p}")
        return None
    d = np.load(p)
    E = d["energies"]
    tr = d["trace"]
    l = d["Lambda"]
    return E, tr, l


lambda_ferretti = load_lambda_trace("output/ed/ferretti")
lambda_brazilian = load_lambda_trace("output/ed/brazilian")

plt.figure(figsize=(8, 6))
if lambda_ferretti is not None:
    E_f, tr_f, l_f = lambda_ferretti
    plt.plot(E_f, tr_f.real, label="Re tr(Lambda) (Ferretti)")
if lambda_brazilian is not None:
    E_b, tr_b, l_b = lambda_brazilian
    plt.plot(E_b, tr_b.real, label="Re tr(Lambda) (Brazilian)")
plt.xlabel("Energy (eV)")
plt.ylabel("Real trace of Lambda")
plt.title("Vertex correction trace (real part)")
plt.legend()
plt.yscale("log")
plt.grid()

plt.figure(figsize=(8, 6))
if lambda_ferretti is not None:
    plt.plot(E_f, tr_f.imag, label="Im tr(Lambda) (Ferretti)")
if lambda_brazilian is not None:
    plt.plot(E_b, tr_b.imag, "-.", label="Im tr(Lambda) (Brazilian)")
plt.xlabel("Energy (eV)")
plt.ylabel("Imag trace of Lambda")
plt.title("Vertex correction trace (imaginary part)")
plt.legend()
plt.grid()

# %%
# Check if Lambda eigenvalue is negative in a given energy range for Brazilian scheme
if lambda_brazilian is not None:
    for i, E in enumerate(E_b):
        eigvals = np.linalg.eigvals(l_b[i])
        # M = l_b[i]
        # M = 0.5*(M + M.conj().T)        # enforce Hermitian for the test
        # ev = np.linalg.eigvalsh(M)      # guaranteed real for Hermitian
        if eigvals.min() < 0:
            print(E, eigvals.min(), eigvals.max())

# %%
# Check if Lambda eigenvalue is negative in a given energy range for Ferretti scheme
if lambda_ferretti is not None:
    for i, E in enumerate(E_b):
        eigvals = np.linalg.eigvals(l_f[i])
        # M = l_f[i]
        # M = 0.5*(M + M.conj().T)        # enforce Hermitian for the test
        # ev = np.linalg.eigvalsh(M)      # guaranteed real for Hermitian
        if eigvals.min() < -1e-10:
            print(E, eigvals.min(), eigvals.max())

# %%
# Check if Lambda is Hermitian in a given energy range for Brazilian scheme
if lambda_brazilian is not None:
    for i, E in enumerate(E_b):
        M = l_b[i]
        diff = np.linalg.norm(M - M.conj().T)
        if diff > 1e-10:
            print(f"Lambda is not Hermitian at energy {E}, difference = {diff}")

# %%
# Check if Lambda is Hermitian in a given energy range for Ferretti scheme
if lambda_ferretti is not None:
    for i, E in enumerate(E_b):
        M = l_f[i]
        diff = np.linalg.norm(M - M.conj().T)
        if diff > 1e-10:
            print(f"Lambda is not Hermitian at energy {E}, difference = {diff}")
# Out:
# Lambda is not Hermitian at energy -4.0, difference = 0.001351538120105944
# Lambda is not Hermitian at energy -3.99, difference = 0.001356463582305979
# Lambda is not Hermitian at energy -3.98, difference = 0.0013614403765889373
# Lambda is not Hermitian at energy -3.97, difference = 0.001366462885948567
# Lambda is not Hermitian at energy -3.96, difference = 0.0013715251443396734
# Lambda is not Hermitian at energy -3.95, difference = 0.0013766207698992516
# Lambda is not Hermitian at energy -3.94, difference = 0.0013817428892265611
# Lambda is not Hermitian at energy -3.93, difference = 0.0013868840509712731
# Lambda is not Hermitian at energy -3.92, difference = 0.001392036126609228
# Lambda is not Hermitian at energy -3.91, difference = 0.0013971901958604095
# Lambda is not Hermitian at energy -3.9, difference = 0.0014023364136321245
# Lambda is not Hermitian at energy -3.89, difference = 0.0014074638546976224
# Lambda is not Hermitian at energy -3.88, difference = 0.0014125603314348318
# Lambda is not Hermitian at energy -3.87, difference = 0.0014176121788734546
# Lambda is not Hermitian at energy -3.86, difference = 0.001422603999871552
# Lambda is not Hermitian at energy -3.85, difference = 0.001427518361497416
# Lambda is not Hermitian at energy -3.84, difference = 0.0014323354313601913
# Lambda is not Hermitian at energy -3.83, difference = 0.0014370325396895936
# Lambda is not Hermitian at energy -3.82, difference = 0.0014415836490866945
# Lambda is not Hermitian at energy -3.81, difference = 0.0014459587087924494
# Lambda is not Hermitian at energy -3.8, difference = 0.0014501228636163302
# Lambda is not Hermitian at energy -3.79, difference = 0.0014540354787203023
# Lambda is not Hermitian at energy -3.78, difference = 0.001457648929449151
# Lambda is not Hermitian at energy -3.77, difference = 0.0014609070891037862
# Lambda is not Hermitian at energy -3.76, difference = 0.0014637434252734512
# Lambda is not Hermitian at energy -3.75, difference = 0.0014660785845385849
# Lambda is not Hermitian at energy -3.74, difference = 0.0014678173022595303
# Lambda is not Hermitian at energy -3.73, difference = 0.0014688444133902426
# Lambda is not Hermitian at energy -3.72, difference = 0.0014690196530902913
# Lambda is not Hermitian at energy -3.71, difference = 0.001468170809763852
# Lambda is not Hermitian at energy -3.7, difference = 0.001466084607490164
# Lambda is not Hermitian at energy -3.69, difference = 0.0014624944177733215
# Lambda is not Hermitian at energy -3.68, difference = 0.0014570634801200568
# Lambda is not Hermitian at energy -3.67, difference = 0.001449361661336906
# Lambda is not Hermitian at energy -3.66, difference = 0.001438832760907525
# Lambda is not Hermitian at energy -3.65, difference = 0.0014247477246497975
# Lambda is not Hermitian at energy -3.64, difference = 0.0014061364225386793
# Lambda is not Hermitian at energy -3.63, difference = 0.0013816860794467747
# Lambda is not Hermitian at energy -3.62, difference = 0.0013495865263175814
# Lambda is not Hermitian at energy -3.61, difference = 0.0013072882764277411
# Lambda is not Hermitian at energy -3.6, difference = 0.0012511132498482713
# Lambda is not Hermitian at energy -3.59, difference = 0.0011756077581697557
# Lambda is not Hermitian at energy -3.58, difference = 0.001072427118962365
# Lambda is not Hermitian at energy -3.57, difference = 0.0009283322989989086
# Lambda is not Hermitian at energy -3.56, difference = 0.0007214234337754633
# Lambda is not Hermitian at energy -3.55, difference = 0.00041370206328739014
# Lambda is not Hermitian at energy -3.54, difference = 6.475564956001684e-05
# Lambda is not Hermitian at energy -3.53, difference = 0.0008474842262895991
# Lambda is not Hermitian at energy -3.52, difference = 0.002204266640950704
# Lambda is not Hermitian at energy -3.51, difference = 0.004637012596045985
# Lambda is not Hermitian at energy -3.5, difference = 0.008577229812264206
# Lambda is not Hermitian at energy -3.49, difference = 0.011774983402573436
# Lambda is not Hermitian at energy -3.48, difference = 0.009614680354119989
# Lambda is not Hermitian at energy -3.47, difference = 0.005424362265562732
# Lambda is not Hermitian at energy -3.46, difference = 0.0026119908955493844
# Lambda is not Hermitian at energy -3.45, difference = 0.0010276649528521923
# Lambda is not Hermitian at energy -3.44, difference = 0.00011564437374694598
# Lambda is not Hermitian at energy -3.43, difference = 0.000442693672727007
# Lambda is not Hermitian at energy -3.42, difference = 0.0008053230747162702
# Lambda is not Hermitian at energy -3.41, difference = 0.001053971791309946
# Lambda is not Hermitian at energy -3.4, difference = 0.0012324483768415798
# Lambda is not Hermitian at energy -3.39, difference = 0.001365689294925245
# Lambda is not Hermitian at energy -3.38, difference = 0.0014686038989731867
# Lambda is not Hermitian at energy -3.37, difference = 0.001550500318036224
# Lambda is not Hermitian at energy -3.36, difference = 0.0016174120320526317
# Lambda is not Hermitian at energy -3.35, difference = 0.0016733794063177273
# Lambda is not Hermitian at energy -3.34, difference = 0.0017211860049328191
# Lambda is not Hermitian at energy -3.33, difference = 0.0017627978409891967
# Lambda is not Hermitian at energy -3.32, difference = 0.0017996343031647967
# Lambda is not Hermitian at energy -3.31, difference = 0.0018327402937260374
# Lambda is not Hermitian at energy -3.3, difference = 0.001862898532879798
# Lambda is not Hermitian at energy -3.29, difference = 0.0018907045847446516
# Lambda is not Hermitian at energy -3.28, difference = 0.0019166180592388503
# Lambda is not Hermitian at energy -3.27, difference = 0.001940998234652974
# Lambda is not Hermitian at energy -3.26, difference = 0.0019641292779414023
# Lambda is not Hermitian at energy -3.25, difference = 0.001986238386698597
# Lambda is not Hermitian at energy -3.24, difference = 0.0020075090305286506
# Lambda is not Hermitian at energy -3.23, difference = 0.0020280907453718413
# Lambda is not Hermitian at energy -3.22, difference = 0.002048106467602445
# Lambda is not Hermitian at energy -3.21, difference = 0.002067658088476196
# Lambda is not Hermitian at energy -3.2, difference = 0.0020868307051479357
# Lambda is not Hermitian at energy -3.19, difference = 0.002105695905983772
# Lambda is not Hermitian at energy -3.18, difference = 0.002124314332677162
# Lambda is not Hermitian at energy -3.17, difference = 0.002142737695370481
# Lambda is not Hermitian at energy -3.16, difference = 0.0021610103701546657
# Lambda is not Hermitian at energy -3.15, difference = 0.0021791706749404913
# Lambda is not Hermitian at energy -3.14, difference = 0.0021972518955947337
# Lambda is not Hermitian at energy -3.13, difference = 0.002215283116673617
# Lambda is not Hermitian at energy -3.12, difference = 0.0022332898981287813
# Lambda is not Hermitian at energy -3.11, difference = 0.002251294829819002
# Lambda is not Hermitian at energy -3.1, difference = 0.002269317988392895
# Lambda is not Hermitian at energy -3.09, difference = 0.0022873773157524556
# Lambda is not Hermitian at energy -3.08, difference = 0.0023054889341165606
# Lambda is not Hermitian at energy -3.07, difference = 0.002323667409578277
# Lambda is not Hermitian at energy -3.06, difference = 0.0023419259735835245
# Lambda is not Hermitian at energy -3.05, difference = 0.0023602767098634347
# Lambda is not Hermitian at energy -3.04, difference = 0.002378730712884551
# Lambda is not Hermitian at energy -3.03, difference = 0.0023972982226951023
# Lambda is not Hermitian at energy -3.02, difference = 0.0024159887401372206
# Lambda is not Hermitian at energy -3.01, difference = 0.0024348111256563753
# Lambda is not Hermitian at energy -3.0, difference = 0.002453773684362391
# Lambda is not Hermitian at energy -2.99, difference = 0.0024728842395044387
# Lambda is not Hermitian at energy -2.98, difference = 0.0024921501961789306
# Lambda is not Hermitian at energy -2.97, difference = 0.0025115785967458754
# Lambda is not Hermitian at energy -2.96, difference = 0.0025311761692015386
# Lambda is not Hermitian at energy -2.95, difference = 0.002550949369548482
# Lambda is not Hermitian at energy -2.94, difference = 0.002570904419023181
# Lambda is not Hermitian at energy -2.93, difference = 0.00259104733692554
# Lambda is not Hermitian at energy -2.92, difference = 0.0026113839696549845
# Lambda is not Hermitian at energy -2.91, difference = 0.0026319200164864063
# Lambda is not Hermitian at energy -2.9, difference = 0.0026526610525269977
# Lambda is not Hermitian at energy -2.89, difference = 0.002673612549232024
# Lambda is not Hermitian at energy -2.88, difference = 0.0026947798927998757
# Lambda is not Hermitian at energy -2.87, difference = 0.0027161684007349623
# Lambda is not Hermitian at energy -2.86, difference = 0.002737783336803594
# Lambda is not Hermitian at energy -2.85, difference = 0.0027596299245924976
# Lambda is not Hermitian at energy -2.84, difference = 0.002781713359855357
# Lambda is not Hermitian at energy -2.83, difference = 0.002804038821787839
# Lambda is not Hermitian at energy -2.82, difference = 0.002826611483376603
# Lambda is not Hermitian at energy -2.81, difference = 0.0028494365209284916
# Lambda is not Hermitian at energy -2.8, difference = 0.0028725191228888536
# Lambda is not Hermitian at energy -2.79, difference = 0.002895864498031426
# Lambda is not Hermitian at energy -2.78, difference = 0.0029194778831119384
# Lambda is not Hermitian at energy -2.77, difference = 0.002943364550022582
# Lambda is not Hermitian at energy -2.76, difference = 0.0029675298125583344
# Lambda is not Hermitian at energy -2.75, difference = 0.0029919790327793774
# Lambda is not Hermitian at energy -2.74, difference = 0.0030167176271019393
# Lambda is not Hermitian at energy -2.73, difference = 0.00304175107207606
# Lambda is not Hermitian at energy -2.72, difference = 0.003067084909940871
# Lambda is not Hermitian at energy -2.71, difference = 0.003092724753985389
# Lambda is not Hermitian at energy -2.7, difference = 0.003118676293724105
# Lambda is not Hermitian at energy -2.69, difference = 0.003144945299910414
# Lambda is not Hermitian at energy -2.68, difference = 0.0031715376294722533
# Lambda is not Hermitian at energy -2.67, difference = 0.0031984592303155326
# Lambda is not Hermitian at energy -2.66, difference = 0.003225716146030043
# Lambda is not Hermitian at energy -2.65, difference = 0.0032533145205879683
# Lambda is not Hermitian at energy -2.64, difference = 0.00328126060293994
# Lambda is not Hermitian at energy -2.63, difference = 0.0033095607516066775
# Lambda is not Hermitian at energy -2.62, difference = 0.0033382214393035767
# Lambda is not Hermitian at energy -2.61, difference = 0.0033672492575409847
# Lambda is not Hermitian at energy -2.6, difference = 0.0033966509216160107
# Lambda is not Hermitian at energy -2.59, difference = 0.0034264332750546787
# Lambda is not Hermitian at energy -2.58, difference = 0.003456603291847175
# Lambda is not Hermitian at energy -2.57, difference = 0.003487168084795437
# Lambda is not Hermitian at energy -2.56, difference = 0.0035181349091820214
# Lambda is not Hermitian at energy -2.55, difference = 0.0035495111668281593
# Lambda is not Hermitian at energy -2.54, difference = 0.0035813044112730555
# Lambda is not Hermitian at energy -2.53, difference = 0.00361352235284223
# Lambda is not Hermitian at energy -2.52, difference = 0.0036461728637012204
# Lambda is not Hermitian at energy -2.51, difference = 0.0036792639830366667
# Lambda is not Hermitian at energy -2.5, difference = 0.00371280392232077
# Lambda is not Hermitian at energy -2.49, difference = 0.0037468010707285265
# Lambda is not Hermitian at energy -2.48, difference = 0.003781264000657561
# Lambda is not Hermitian at energy -2.47, difference = 0.0038162014733825527
# Lambda is not Hermitian at energy -2.46, difference = 0.003851622444865108
# Lambda is not Hermitian at energy -2.45, difference = 0.0038875360717097536
# Lambda is not Hermitian at energy -2.44, difference = 0.003923951717285932
# Lambda is not Hermitian at energy -2.43, difference = 0.003960878958003216
# Lambda is not Hermitian at energy -2.42, difference = 0.003998327589786546
# Lambda is not Hermitian at energy -2.41, difference = 0.004036307634716221
# Lambda is not Hermitian at energy -2.4, difference = 0.0040748293478874344
# Lambda is not Hermitian at energy -2.39, difference = 0.004113903224450746
# Lambda is not Hermitian at energy -2.38, difference = 0.004153540006888884
# Lambda is not Hermitian at energy -2.37, difference = 0.004193750692504604
# Lambda is not Hermitian at energy -2.36, difference = 0.004234546541153497
# Lambda is not Hermitian at energy -2.35, difference = 0.004275939083214851
# Lambda is not Hermitian at energy -2.34, difference = 0.004317940127827184
# Lambda is not Hermitian at energy -2.33, difference = 0.004360561771386027
# Lambda is not Hermitian at energy -2.32, difference = 0.004403816406324181
# Lambda is not Hermitian at energy -2.31, difference = 0.004447716730185524
# Lambda is not Hermitian at energy -2.3, difference = 0.004492275755005262
# Lambda is not Hermitian at energy -2.29, difference = 0.0045375068170008135
# Lambda is not Hermitian at energy -2.28, difference = 0.00458342358660322
# Lambda is not Hermitian at energy -2.27, difference = 0.004630040078830873
# Lambda is not Hermitian at energy -2.26, difference = 0.004677370664024406
# Lambda is not Hermitian at energy -2.25, difference = 0.004725430078958806
# Lambda is not Hermitian at energy -2.24, difference = 0.004774233438348313
# Lambda is not Hermitian at energy -2.23, difference = 0.004823796246760494
# Lambda is not Hermitian at energy -2.22, difference = 0.004874134410957631
# Lambda is not Hermitian at energy -2.21, difference = 0.004925264252684593
# Lambda is not Hermitian at energy -2.2, difference = 0.004977202521921785
# Lambda is not Hermitian at energy -2.19, difference = 0.005029966410623055
# Lambda is not Hermitian at energy -2.18, difference = 0.005083573566957872
# Lambda is not Hermitian at energy -2.17, difference = 0.0051380421100865065
# Lambda is not Hermitian at energy -2.16, difference = 0.005193390645482009
# Lambda is not Hermitian at energy -2.15, difference = 0.005249638280831874
# Lambda is not Hermitian at energy -2.14, difference = 0.0053068046425380645
# Lambda is not Hermitian at energy -2.13, difference = 0.005364909892846496
# Lambda is not Hermitian at energy -2.12, difference = 0.005423974747632028
# Lambda is not Hermitian at energy -2.11, difference = 0.005484020494867775
# Lambda is not Hermitian at energy -2.1, difference = 0.005545069013812333
# Lambda is not Hermitian at energy -2.09, difference = 0.005607142794943081
# Lambda is not Hermitian at energy -2.08, difference = 0.005670264960671625
# Lambda is not Hermitian at energy -2.07, difference = 0.00573445928687926
# Lambda is not Hermitian at energy -2.06, difference = 0.005799750225305669
# Lambda is not Hermitian at energy -2.05, difference = 0.005866162926832644
# Lambda is not Hermitian at energy -2.04, difference = 0.005933723265703174
# Lambda is not Hermitian at energy -2.03, difference = 0.0060024578647223615
# Lambda is not Hermitian at energy -2.02, difference = 0.006072394121480023
# Lambda is not Hermitian at energy -2.01, difference = 0.006143560235651272
# Lambda is not Hermitian at energy -2.0, difference = 0.006215985237417142
# Lambda is not Hermitian at energy -1.99, difference = 0.006289699017065376
# Lambda is not Hermitian at energy -1.98, difference = 0.00636473235582582
# Lambda is not Hermitian at energy -1.97, difference = 0.0064411169579976935
# Lambda is not Hermitian at energy -1.96, difference = 0.00651888548443437
# Lambda is not Hermitian at energy -1.95, difference = 0.006598071587449459
# Lambda is not Hermitian at energy -1.94, difference = 0.006678709947214576
# Lambda is not Hermitian at energy -1.93, difference = 0.0067608363097241865
# Lambda is not Hermitian at energy -1.92, difference = 0.006844487526400513
# Lambda is not Hermitian at energy -1.91, difference = 0.006929701595425488
# Lambda is not Hermitian at energy -1.9, difference = 0.007016517704882938
# Lambda is not Hermitian at energy -1.89, difference = 0.007104976277803303
# Lambda is not Hermitian at energy -1.88, difference = 0.007195119019209071
# Lambda is not Hermitian at energy -1.87, difference = 0.007286988965260191
# Lambda is not Hermitian at energy -1.86, difference = 0.007380630534609507
# Lambda is not Hermitian at energy -1.85, difference = 0.007476089582084425
# Lambda is not Hermitian at energy -1.84, difference = 0.007573413454809691
# Lambda is not Hermitian at energy -1.83, difference = 0.00767265105090724
# Lambda is not Hermitian at energy -1.82, difference = 0.007773852880904291
# Lambda is not Hermitian at energy -1.81, difference = 0.007877071131992432
# Lambda is not Hermitian at energy -1.8, difference = 0.007982359735296938
# Lambda is not Hermitian at energy -1.79, difference = 0.00808977443630942
# Lambda is not Hermitian at energy -1.78, difference = 0.008199372868662106
# Lambda is not Hermitian at energy -1.77, difference = 0.00831121463142279
# Lambda is not Hermitian at energy -1.76, difference = 0.008425361370107385
# Lambda is not Hermitian at energy -1.75, difference = 0.008541876861608934
# Lambda is not Hermitian at energy -1.74, difference = 0.008660827103269781
# Lambda is not Hermitian at energy -1.73, difference = 0.008782280406321865
# Lambda is not Hermitian at energy -1.72, difference = 0.008906307493947758
# Lambda is not Hermitian at energy -1.71, difference = 0.009032981604223273
# Lambda is not Hermitian at energy -1.7, difference = 0.009162378598214824
# Lambda is not Hermitian at energy -1.69, difference = 0.009294577073547394
# Lambda is not Hermitian at energy -1.68, difference = 0.009429658483731531
# Lambda is not Hermitian at energy -1.67, difference = 0.009567707263627106
# Lambda is not Hermitian at energy -1.66, difference = 0.00970881096135886
# Lambda is not Hermitian at energy -1.65, difference = 0.00985306037710284
# Lambda is not Hermitian at energy -1.64, difference = 0.010000549709152007
# Lambda is not Hermitian at energy -1.63, difference = 0.010151376707677587
# Lambda is not Hermitian at energy -1.62, difference = 0.010305642836683239
# Lambda is not Hermitian at energy -1.61, difference = 0.010463453444614449
# Lambda is not Hermitian at energy -1.6, difference = 0.010624917944168807
# Lambda is not Hermitian at energy -1.59, difference = 0.010790150001381433
# Lambda is not Hermitian at energy -1.58, difference = 0.010959267736419446
# Lambda is not Hermitian at energy -1.57, difference = 0.01113239393629778
# Lambda is not Hermitian at energy -1.56, difference = 0.011309656274089355
# Lambda is not Hermitian at energy -1.55, difference = 0.011491187545789263
# Lambda is not Hermitian at energy -1.54, difference = 0.011677125919793556
# Lambda is not Hermitian at energy -1.53, difference = 0.011867615199338809
# Lambda is not Hermitian at energy -1.52, difference = 0.012062805100404545
# Lambda is not Hermitian at energy -1.51, difference = 0.012262851545886288
# Lambda is not Hermitian at energy -1.5, difference = 0.012467916976956877
# Lambda is not Hermitian at energy -1.49, difference = 0.012678170682797054
# Lambda is not Hermitian at energy -1.48, difference = 0.012893789149945075
# Lambda is not Hermitian at energy -1.47, difference = 0.013114956432625067
# Lambda is not Hermitian at energy -1.46, difference = 0.013341864545480635
# Lambda is not Hermitian at energy -1.45, difference = 0.013574713880300305
# Lambda is not Hermitian at energy -1.44, difference = 0.013813713648410483
# Lambda is not Hermitian at energy -1.43, difference = 0.014059082350562762
# Lambda is not Hermitian at energy -1.42, difference = 0.014311048276290539
# Lambda is not Hermitian at energy -1.41, difference = 0.014569850034856033
# Lambda is not Hermitian at energy -1.4, difference = 0.014835737120100067
# Lambda is not Hermitian at energy -1.39, difference = 0.015108970511691217
# Lambda is not Hermitian at energy -1.38, difference = 0.015389823315473606
# Lambda is not Hermitian at energy -1.37, difference = 0.01567858144585007
# Lambda is not Hermitian at energy -1.36, difference = 0.015975544353387477
# Lambda is not Hermitian at energy -1.35, difference = 0.01628102580109218
# Lambda is not Hermitian at energy -1.34, difference = 0.01659535469311941
# Lambda is not Hermitian at energy -1.33, difference = 0.016918875960002227
# Lambda is not Hermitian at energy -1.32, difference = 0.017251951504843727
# Lambda is not Hermitian at energy -1.31, difference = 0.017594961215321694
# Lambda is not Hermitian at energy -1.3, difference = 0.017948304046790237
# Lambda is not Hermitian at energy -1.29, difference = 0.018312399182236806
# Lambda is not Hermitian at energy -1.28, difference = 0.01868768727539924
# Lambda is not Hermitian at energy -1.27, difference = 0.019074631783919146
# Lambda is not Hermitian at energy -1.26, difference = 0.019473720400064183
# Lambda is not Hermitian at energy -1.25, difference = 0.019885466587264387
# Lambda is not Hermitian at energy -1.24, difference = 0.020310411231499854
# Lambda is not Hermitian at energy -1.23, difference = 0.020749124417456355
# Lambda is not Hermitian at energy -1.22, difference = 0.02120220734033717
# Lambda is not Hermitian at energy -1.21, difference = 0.021670294365300158
# Lambda is not Hermitian at energy -1.2, difference = 0.02215405524769245
# Lambda is not Hermitian at energy -1.19, difference = 0.02265419752858857
# Lambda is not Hermitian at energy -1.18, difference = 0.023171469121630043
# Lambda is not Hermitian at energy -1.17, difference = 0.023706661108821706
# Lambda is not Hermitian at energy -1.16, difference = 0.02426061076479839
# Lambda is not Hermitian at energy -1.15, difference = 0.024834204831146883
# Lambda is not Hermitian at energy -1.14, difference = 0.025428383064687893
# Lambda is not Hermitian at energy -1.13, difference = 0.02604414208622802
# Lambda is not Hermitian at energy -1.12, difference = 0.026682539559210447
# Lambda is not Hermitian at energy -1.11, difference = 0.027344698730974042
# Lambda is not Hermitian at energy -1.1, difference = 0.028031813373022844
# Lambda is not Hermitian at energy -1.09, difference = 0.028745153160878868
# Lambda is not Hermitian at energy -1.08, difference = 0.029486069538777866
# Lambda is not Hermitian at energy -1.07, difference = 0.030256002119788728
# Lambda is not Hermitian at energy -1.06, difference = 0.031056485677943852
# Lambda is not Hermitian at energy -1.05, difference = 0.031889157795786764
# Lambda is not Hermitian at energy -1.04, difference = 0.03275576723848531
# Lambda is not Hermitian at energy -1.03, difference = 0.03365818313446146
# Lambda is not Hermitian at energy -1.02, difference = 0.034598405052526614
# Lambda is not Hermitian at energy -1.01, difference = 0.03557857407695978
# Lambda is not Hermitian at energy -1.0, difference = 0.03660098499505745
# Lambda is not Hermitian at energy -0.99, difference = 0.03766809972669167
# Lambda is not Hermitian at energy -0.98, difference = 0.03878256214261162
# Lambda is not Hermitian at energy -0.97, difference = 0.039947214438025944
# Lambda is not Hermitian at energy -0.96, difference = 0.04116511525079861
# Lambda is not Hermitian at energy -0.95, difference = 0.042439559739911106
# Lambda is not Hermitian at energy -0.94, difference = 0.04377410187029807
# Lambda is not Hermitian at energy -0.93, difference = 0.04517257918546045
# Lambda is not Hermitian at energy -0.92, difference = 0.04663914039027736
# Lambda is not Hermitian at energy -0.91, difference = 0.048178276114204485
# Lambda is not Hermitian at energy -0.9, difference = 0.0497948532808003
# Lambda is not Hermitian at energy -0.89, difference = 0.05149415357476816
# Lambda is not Hermitian at energy -0.88, difference = 0.05328191657422778
# Lambda is not Hermitian at energy -0.87, difference = 0.05516438820594617
# Lambda is not Hermitian at energy -0.86, difference = 0.0571483752873964
# Lambda is not Hermitian at energy -0.85, difference = 0.05924130704503092
# Lambda is not Hermitian at energy -0.84, difference = 0.061451304646991965
# Lambda is not Hermitian at energy -0.83, difference = 0.06378725996551862
# Lambda is not Hermitian at energy -0.82, difference = 0.06625892499550502
# Lambda is not Hermitian at energy -0.81, difference = 0.06887701360842714
# Lambda is not Hermitian at energy -0.8, difference = 0.07165331762434303
# Lambda is not Hermitian at energy -0.79, difference = 0.07460083955034509
# Lambda is not Hermitian at energy -0.78, difference = 0.07773394477590505
# Lambda is not Hermitian at energy -0.77, difference = 0.08106853655208046
# Lambda is not Hermitian at energy -0.76, difference = 0.08462225773502968
# Lambda is not Hermitian at energy -0.75, difference = 0.08841472407352254
# Lambda is not Hermitian at energy -0.74, difference = 0.09246779480156524
# Lambda is not Hermitian at energy -0.73, difference = 0.09680588750769697
# Lambda is not Hermitian at energy -0.72, difference = 0.10145634575198911
# Lambda is not Hermitian at energy -0.71, difference = 0.10644986976808825
# Lambda is not Hermitian at energy -0.7, difference = 0.11182102292182397
# Lambda is not Hermitian at energy -0.69, difference = 0.11760882953223034
# Lambda is not Hermitian at energy -0.68, difference = 0.12385748336921065
# Lambda is not Hermitian at energy -0.67, difference = 0.13061719085514228
# Lambda is not Hermitian at energy -0.66, difference = 0.13794517902265166
# Lambda is not Hermitian at energy -0.65, difference = 0.1459069060304456
# Lambda is not Hermitian at energy -0.64, difference = 0.154577522071643
# Lambda is not Hermitian at energy -0.63, difference = 0.16404364158583493
# Lambda is not Hermitian at energy -0.62, difference = 0.17440550485328524
# Lambda is not Hermitian at energy -0.61, difference = 0.1857796297579097
# Lambda is not Hermitian at energy -0.6, difference = 0.19830208478435765
# Lambda is not Hermitian at energy -0.59, difference = 0.2121325550304316
# Lambda is not Hermitian at energy -0.58, difference = 0.22745942825977478
# Lambda is not Hermitian at energy -0.57, difference = 0.24450620369181164
# Lambda is not Hermitian at energy -0.56, difference = 0.263539630934671
# Lambda is not Hermitian at energy -0.55, difference = 0.2848801329254933
# Lambda is not Hermitian at energy -0.54, difference = 0.3089152739701473
# Lambda is not Hermitian at energy -0.53, difference = 0.33611733082018974
# Lambda is not Hermitian at energy -0.52, difference = 0.36706645559969125
# Lambda is not Hermitian at energy -0.51, difference = 0.40248155375601463
# Lambda is not Hermitian at energy -0.5, difference = 0.443261948550921
# Lambda is not Hermitian at energy -0.49, difference = 0.4905443449535589
# Lambda is not Hermitian at energy -0.48, difference = 0.5457818359828763
# Lambda is not Hermitian at energy -0.47, difference = 0.6108552130081997
# Lambda is not Hermitian at energy -0.46, difference = 0.6882325111548647
# Lambda is not Hermitian at energy -0.45, difference = 0.7812020706461826
# Lambda is not Hermitian at energy -0.44, difference = 0.8942202086666365
# Lambda is not Hermitian at energy -0.43, difference = 1.0334420973558933
# Lambda is not Hermitian at energy -0.42, difference = 1.207553755324716
# Lambda is not Hermitian at energy -0.41, difference = 1.4291145107073688
# Lambda is not Hermitian at energy -0.4, difference = 1.7167952955298014
# Lambda is not Hermitian at energy -0.39, difference = 2.099250861505766
# Lambda is not Hermitian at energy -0.38, difference = 2.6221024306373333
# Lambda is not Hermitian at energy -0.37, difference = 3.3611244958742947
# Lambda is not Hermitian at energy -0.36, difference = 4.448422572835298
# Lambda is not Hermitian at energy -0.35, difference = 6.12702680654396
# Lambda is not Hermitian at energy -0.34, difference = 8.868627551174104
# Lambda is not Hermitian at energy -0.33, difference = 13.617307761052187
# Lambda is not Hermitian at energy -0.32, difference = 22.10036869591261
# Lambda is not Hermitian at energy -0.31, difference = 35.46916940467304
# Lambda is not Hermitian at energy -0.3, difference = 44.89919656914876
# Lambda is not Hermitian at energy -0.29, difference = 36.384862016457994
# Lambda is not Hermitian at energy -0.28, difference = 22.815927902865905
# Lambda is not Hermitian at energy -0.27, difference = 14.023803680932732
# Lambda is not Hermitian at energy -0.26, difference = 9.09762043286857
# Lambda is not Hermitian at energy -0.25, difference = 6.26316861238185
# Lambda is not Hermitian at energy -0.24, difference = 4.534293133726452
# Lambda is not Hermitian at energy -0.23, difference = 3.4181876391112933
# Lambda is not Hermitian at energy -0.22, difference = 2.661719164525687
# Lambda is not Hermitian at energy -0.21, difference = 2.127774756969913
# Lambda is not Hermitian at energy -0.2, difference = 1.737966011045259
# Lambda is not Hermitian at energy -0.19, difference = 1.4452348109128035
# Lambda is not Hermitian at energy -0.18, difference = 1.2200983498747726
# Lambda is not Hermitian at energy -0.17, difference = 1.0433880940227824
# Lambda is not Hermitian at energy -0.16, difference = 0.9022344696216856
# Lambda is not Hermitian at energy -0.15, difference = 0.7877516567339342
# Lambda is not Hermitian at energy -0.14, difference = 0.6936520803202417
# Lambda is not Hermitian at energy -0.13, difference = 0.6153894352676933
# Lambda is not Hermitian at energy -0.12, difference = 0.5496128281449009
# Lambda is not Hermitian at energy -0.11, difference = 0.4938098567519436
# Lambda is not Hermitian at energy -0.1, difference = 0.4460676867876155
# Lambda is not Hermitian at energy -0.09, difference = 0.4049097017951337
# Lambda is not Hermitian at energy -0.08, difference = 0.36918166989205176
# Lambda is not Hermitian at energy -0.07, difference = 0.3379710313909851
# Lambda is not Hermitian at energy -0.06, difference = 0.3105487605508671
# Lambda is not Hermitian at energy -0.05, difference = 0.2863268794271784
# Lambda is not Hermitian at energy -0.04, difference = 0.2648269963605272
# Lambda is not Hermitian at energy -0.03, difference = 0.24565672283478618
# Lambda is not Hermitian at energy -0.02, difference = 0.22849179592672586
# Lambda is not Hermitian at energy -0.01, difference = 0.213062384091957
# Lambda is not Hermitian at energy -0.0, difference = 0.199142495468782
# Lambda is not Hermitian at energy 0.01, difference = 0.186541711737934
# Lambda is not Hermitian at energy 0.02, difference = 0.17509868252549293
# Lambda is not Hermitian at energy 0.03, difference = 0.16467596501776977
# Lambda is not Hermitian at energy 0.04, difference = 0.15515590039413368
# Lambda is not Hermitian at energy 0.05, difference = 0.14643729591439436
# Lambda is not Hermitian at energy 0.06, difference = 0.13843273784386018
# Lambda is not Hermitian at energy 0.07, difference = 0.13106640190322863
# Lambda is not Hermitian at energy 0.08, difference = 0.12427225877819684
# Lambda is not Hermitian at energy 0.09, difference = 0.11799259534652164
# Lambda is not Hermitian at energy 0.1, difference = 0.11217678975221854
# Lambda is not Hermitian at energy 0.11, difference = 0.10678029175928759
# Lambda is not Hermitian at energy 0.12, difference = 0.10176377001862245
# Lambda is not Hermitian at energy 0.13, difference = 0.09709239575854754
# Lambda is not Hermitian at energy 0.14, difference = 0.09273523853055907
# Lambda is not Hermitian at energy 0.15, difference = 0.08866475442846178
# Lambda is not Hermitian at energy 0.16, difference = 0.08485635096392234
# Lambda is not Hermitian at energy 0.17, difference = 0.08128801575941624
# Lambda is not Hermitian at energy 0.18, difference = 0.07793999858762826
# Lambda is not Hermitian at energy 0.19, difference = 0.07479453817922768
# Lambda is not Hermitian at energy 0.2, difference = 0.0718356267412312
# Lambda is not Hermitian at energy 0.21, difference = 0.06904880635510803
# Lambda is not Hermitian at energy 0.22, difference = 0.06642099241821561
# Lambda is not Hermitian at energy 0.23, difference = 0.06394032010192728
# Lambda is not Hermitian at energy 0.24, difference = 0.0615960104616096
# Lambda is not Hermitian at energy 0.25, difference = 0.05937825337667228
# Lambda is not Hermitian at energy 0.26, difference = 0.057278104946710984
# Lambda is not Hermitian at energy 0.27, difference = 0.05528739734003871
# Lambda is not Hermitian at energy 0.28, difference = 0.05339865939706251
# Lambda is not Hermitian at energy 0.29, difference = 0.05160504654761368
# Lambda is not Hermitian at energy 0.3, difference = 0.049900278814604244
# Lambda is not Hermitian at energy 0.31, difference = 0.048278585855349304
# Lambda is not Hermitian at energy 0.32, difference = 0.04673465814242287
# Lambda is not Hermitian at energy 0.33, difference = 0.045263603512797304
# Lambda is not Hermitian at energy 0.34, difference = 0.04386090842129917
# Lambda is not Hermitian at energy 0.35, difference = 0.04252240332533987
# Lambda is not Hermitian at energy 0.36, difference = 0.04124423170522678
# Lambda is not Hermitian at energy 0.37, difference = 0.040022822290248956
# Lambda is not Hermitian at energy 0.38, difference = 0.03885486411705394
# Lambda is not Hermitian at energy 0.39, difference = 0.03773728409506001
# Lambda is not Hermitian at energy 0.4, difference = 0.036667226795068154
# Lambda is not Hermitian at energy 0.41, difference = 0.03564203621286581
# Lambda is not Hermitian at energy 0.42, difference = 0.0346592392903698
# Lambda is not Hermitian at energy 0.43, difference = 0.0337165310033943
# Lambda is not Hermitian at energy 0.44, difference = 0.03281176084816053
# Lambda is not Hermitian at energy 0.45, difference = 0.031942920578625786
# Lambda is not Hermitian at energy 0.46, difference = 0.031108133064071758
# Lambda is not Hermitian at energy 0.47, difference = 0.030305642151525657
# Lambda is not Hermitian at energy 0.48, difference = 0.029533803430789592
# Lambda is not Hermitian at energy 0.49, difference = 0.028791075811416534
# Lambda is not Hermitian at energy 0.5, difference = 0.02807601383106572
# Lambda is not Hermitian at energy 0.51, difference = 0.027387260623569828
# Lambda is not Hermitian at energy 0.52, difference = 0.02672354148284316
# Lambda is not Hermitian at energy 0.53, difference = 0.026083657965630207
# Lambda is not Hermitian at energy 0.54, difference = 0.02546648248216087
# Lambda is not Hermitian at energy 0.55, difference = 0.024870953329117946
# Lambda is not Hermitian at energy 0.56, difference = 0.02429607012408011
# Lambda is not Hermitian at energy 0.57, difference = 0.02374088960477427
# Lambda is not Hermitian at energy 0.58, difference = 0.02320452176020835
# Lambda is not Hermitian at energy 0.59, difference = 0.022686126264063144
# Lambda is not Hermitian at energy 0.6, difference = 0.022184909183648297
# Lambda is not Hermitian at energy 0.61, difference = 0.0217001199403682
# Lambda is not Hermitian at energy 0.62, difference = 0.021231048499967646
# Lambda is not Hermitian at energy 0.63, difference = 0.020777022772922253
# Lambda is not Hermitian at energy 0.64, difference = 0.020337406207201834
# Lambda is not Hermitian at energy 0.65, difference = 0.0199115955573136
# Lambda is not Hermitian at energy 0.66, difference = 0.01949901881502228
# Lambda is not Hermitian at energy 0.67, difference = 0.019099133288501748
# Lambda is not Hermitian at energy 0.68, difference = 0.01871142381786968
# Lambda is not Hermitian at energy 0.69, difference = 0.018335401116154264
# Lambda is not Hermitian at energy 0.7, difference = 0.01797060022571928
# Lambda is not Hermitian at energy 0.71, difference = 0.017616579081052002
# Lambda is not Hermitian at energy 0.72, difference = 0.017272917169623894
# Lambda is not Hermitian at energy 0.73, difference = 0.016939214283250164
# Lambda is not Hermitian at energy 0.74, difference = 0.016615089353026444
# Lambda is not Hermitian at energy 0.75, difference = 0.01630017936150775
# Lambda is not Hermitian at energy 0.76, difference = 0.015994138326337067
# Lambda is not Hermitian at energy 0.77, difference = 0.01569663635000824
# Lambda is not Hermitian at energy 0.78, difference = 0.015407358730890778
# Lambda is not Hermitian at energy 0.79, difference = 0.015126005131044961
# Lambda is not Hermitian at energy 0.8, difference = 0.014852288796720601
# Lambda is not Hermitian at energy 0.81, difference = 0.014585935827759454
# Lambda is not Hermitian at energy 0.82, difference = 0.01432668449242845
# Lambda is not Hermitian at energy 0.83, difference = 0.014074284584483617
# Lambda is not Hermitian at energy 0.84, difference = 0.013828496819515378
# Lambda is not Hermitian at energy 0.85, difference = 0.013589092267857168
# Lambda is not Hermitian at energy 0.86, difference = 0.0133558518215487
# Lambda is not Hermitian at energy 0.87, difference = 0.013128565693035603
# Lambda is not Hermitian at energy 0.88, difference = 0.012907032943465773
# Lambda is not Hermitian at energy 0.89, difference = 0.012691061038600645
# Lambda is not Hermitian at energy 0.9, difference = 0.01248046543051069
# Lambda is not Hermitian at energy 0.91, difference = 0.012275069163359008
# Lambda is not Hermitian at energy 0.92, difference = 0.012074702501698136
# Lambda is not Hermitian at energy 0.93, difference = 0.011879202579825422
# Lambda is not Hermitian at energy 0.94, difference = 0.011688413070843546
# Lambda is not Hermitian at energy 0.95, difference = 0.011502183874170093
# Lambda is not Hermitian at energy 0.96, difference = 0.011320370820331993
# Lambda is not Hermitian at energy 0.97, difference = 0.011142835391958351
# Lambda is not Hermitian at energy 0.98, difference = 0.01096944445996681
# Lambda is not Hermitian at energy 0.99, difference = 0.010800070034001496
# Lambda is not Hermitian at energy 1.0, difference = 0.010634589026253865
# Lambda is not Hermitian at energy 1.01, difference = 0.010472883027848677
# Lambda is not Hermitian at energy 1.02, difference = 0.010314838097039385
# Lambda is not Hermitian at energy 1.03, difference = 0.010160344558504729
# Lambda is not Hermitian at energy 1.04, difference = 0.010009296813085912
# Lambda is not Hermitian at energy 1.05, difference = 0.009861593157349786
# Lambda is not Hermitian at energy 1.06, difference = 0.009717135612400934
# Lambda is not Hermitian at energy 1.07, difference = 0.009575829761405889
# Lambda is not Hermitian at energy 1.08, difference = 0.009437584595325952
# Lambda is not Hermitian at energy 1.09, difference = 0.009302312366387514
# Lambda is not Hermitian at energy 1.1, difference = 0.009169928448851004
# Lambda is not Hermitian at energy 1.11, difference = 0.009040351206664403
# Lambda is not Hermitian at energy 1.12, difference = 0.008913501867616587
# Lambda is not Hermitian at energy 1.13, difference = 0.008789304403626201
# Lambda is not Hermitian at energy 1.14, difference = 0.008667685416828753
# Lambda is not Hermitian at energy 1.15, difference = 0.008548574031142012
# Lambda is not Hermitian at energy 1.16, difference = 0.008431901789010083
# Lambda is not Hermitian at energy 1.17, difference = 0.008317602553047695
# Lambda is not Hermitian at energy 1.18, difference = 0.008205612412317724
# Lambda is not Hermitian at energy 1.19, difference = 0.008095869592996992
# Lambda is not Hermitian at energy 1.2, difference = 0.007988314373194689
# Lambda is not Hermitian at energy 1.21, difference = 0.007882889001706653
# Lambda is not Hermitian at energy 1.22, difference = 0.0077795376204967395
# Lambda is not Hermitian at energy 1.23, difference = 0.007678206190712783
# Lambda is not Hermitian at energy 1.24, difference = 0.007578842422054137
# Lambda is not Hermitian at energy 1.25, difference = 0.0074813957053163375
# Lambda is not Hermitian at energy 1.26, difference = 0.007385817047953433
# Lambda is not Hermitian at energy 1.27, difference = 0.00729205901250362
# Lambda is not Hermitian at energy 1.28, difference = 0.007200075657732054
# Lambda is not Hermitian at energy 1.29, difference = 0.007109822482357874
# Lambda is not Hermitian at energy 1.3, difference = 0.007021256371232779
# Lambda is not Hermitian at energy 1.31, difference = 0.006934335543853972
# Lambda is not Hermitian at energy 1.32, difference = 0.006849019505093288
# Lambda is not Hermitian at energy 1.33, difference = 0.0067652689980347794
# Lambda is not Hermitian at energy 1.34, difference = 0.006683045958819744
# Lambda is not Hermitian at energy 1.35, difference = 0.006602313473400739
# Lambda is not Hermitian at energy 1.36, difference = 0.00652303573611344
# Lambda is not Hermitian at energy 1.37, difference = 0.006445178009978755
# Lambda is not Hermitian at energy 1.38, difference = 0.0063687065886543605
# Lambda is not Hermitian at energy 1.39, difference = 0.006293588759957414
# Lambda is not Hermitian at energy 1.4, difference = 0.006219792770883507
# Lambda is not Hermitian at energy 1.41, difference = 0.006147287794054402
# Lambda is not Hermitian at energy 1.42, difference = 0.006076043895525166
# Lambda is not Hermitian at energy 1.43, difference = 0.006006032003892915
# Lambda is not Hermitian at energy 1.44, difference = 0.005937223880639666
# Lambda is not Hermitian at energy 1.45, difference = 0.005869592091663185
# Lambda is not Hermitian at energy 1.46, difference = 0.0058031099799326835
# Lambda is not Hermitian at energy 1.47, difference = 0.005737751639224434
# Lambda is not Hermitian at energy 1.48, difference = 0.005673491888887536
# Lambda is not Hermitian at energy 1.49, difference = 0.005610306249590974
# Lambda is not Hermitian at energy 1.5, difference = 0.005548170920014065
# Lambda is not Hermitian at energy 1.51, difference = 0.005487062754434725
# Lambda is not Hermitian at energy 1.52, difference = 0.005426959241175103
# Lambda is not Hermitian at energy 1.53, difference = 0.005367838481873666
# Lambda is not Hermitian at energy 1.54, difference = 0.005309679171537037
# Lambda is not Hermitian at energy 1.55, difference = 0.0052524605793575155
# Lambda is not Hermitian at energy 1.56, difference = 0.005196162530222355
# Lambda is not Hermitian at energy 1.57, difference = 0.005140765386995058
# Lambda is not Hermitian at energy 1.58, difference = 0.005086250033206642
# Lambda is not Hermitian at energy 1.59, difference = 0.005032597856619393
# Lambda is not Hermitian at energy 1.6, difference = 0.004979790733765072
# Lambda is not Hermitian at energy 1.61, difference = 0.004927811014325903
# Lambda is not Hermitian at energy 1.62, difference = 0.004876641506068404
# Lambda is not Hermitian at energy 1.63, difference = 0.004826265460850937
# Lambda is not Hermitian at energy 1.64, difference = 0.0047766665612312955
# Lambda is not Hermitian at energy 1.65, difference = 0.00472782890691121
# Lambda is not Hermitian at energy 1.66, difference = 0.0046797370021494965
# Lambda is not Hermitian at energy 1.67, difference = 0.004632375743377575
# Lambda is not Hermitian at energy 1.68, difference = 0.004585730407406462
# Lambda is not Hermitian at energy 1.69, difference = 0.0045397866399636
# Lambda is not Hermitian at energy 1.7, difference = 0.004494530444643917
# Lambda is not Hermitian at energy 1.71, difference = 0.004449948172261352
# Lambda is not Hermitian at energy 1.72, difference = 0.004406026510557638
# Lambda is not Hermitian at energy 1.73, difference = 0.004362752474262997
# Lambda is not Hermitian at energy 1.74, difference = 0.004320113395499186
# Lambda is not Hermitian at energy 1.75, difference = 0.004278096914512852
# Lambda is not Hermitian at energy 1.76, difference = 0.0042366909707154754
# Lambda is not Hermitian at energy 1.77, difference = 0.004195883794033435
# Lambda is not Hermitian at energy 1.78, difference = 0.004155663896540762
# Lambda is not Hermitian at energy 1.79, difference = 0.004116020064378142
# Lambda is not Hermitian at energy 1.8, difference = 0.004076941349933033
# Lambda is not Hermitian at energy 1.81, difference = 0.004038417064286384
# Lambda is not Hermitian at energy 1.82, difference = 0.004000436769900381
# Lambda is not Hermitian at energy 1.83, difference = 0.0039629902735516115
# Lambda is not Hermitian at energy 1.84, difference = 0.003926067619489462
# Lambda is not Hermitian at energy 1.85, difference = 0.003889659082823106
# Lambda is not Hermitian at energy 1.86, difference = 0.003853755163113225
# Lambda is not Hermitian at energy 1.87, difference = 0.00381834657817852
# Lambda is not Hermitian at energy 1.88, difference = 0.0037834242580941277
# Lambda is not Hermitian at energy 1.89, difference = 0.0037489793393829436
# Lambda is not Hermitian at energy 1.9, difference = 0.003715003159391306
# Lambda is not Hermitian at energy 1.91, difference = 0.0036814872508429963
# Lambda is not Hermitian at energy 1.92, difference = 0.0036484233365655324
# Lambda is not Hermitian at energy 1.93, difference = 0.00361580332437287
# Lambda is not Hermitian at energy 1.94, difference = 0.003583619302120222
# Lambda is not Hermitian at energy 1.95, difference = 0.00355186353289578
# Lambda is not Hermitian at energy 1.96, difference = 0.003520528450371578
# Lambda is not Hermitian at energy 1.97, difference = 0.003489606654316516
# Lambda is not Hermitian at energy 1.98, difference = 0.0034590909061832666
# Lambda is not Hermitian at energy 1.99, difference = 0.003428974124910836
# Lambda is not Hermitian at energy 2.0, difference = 0.0033992493828352453
# Lambda is not Hermitian at energy 2.01, difference = 0.0033699099016820033
# Lambda is not Hermitian at energy 2.02, difference = 0.0033409490485236397
# Lambda is not Hermitian at energy 2.03, difference = 0.0033123603323255363
# Lambda is not Hermitian at energy 2.04, difference = 0.00328413740013907
# Lambda is not Hermitian at energy 2.05, difference = 0.003256274033609713
# Lambda is not Hermitian at energy 2.06, difference = 0.003228764145527752
# Lambda is not Hermitian at energy 2.07, difference = 0.0032016017765151717
# Lambda is not Hermitian at energy 2.08, difference = 0.0031747810917875856
# Lambda is not Hermitian at energy 2.09, difference = 0.0031482963780141895
# Lambda is not Hermitian at energy 2.1, difference = 0.003122142040279975
# Lambda is not Hermitian at energy 2.11, difference = 0.003096312599110713
# Lambda is not Hermitian at energy 2.12, difference = 0.0030708026876115394
# Lambda is not Hermitian at energy 2.13, difference = 0.0030456070486624422
# Lambda is not Hermitian at energy 2.14, difference = 0.003020720532211427
# Lambda is not Hermitian at energy 2.15, difference = 0.0029961380926291493
# Lambda is not Hermitian at energy 2.16, difference = 0.0029718547861454624
# Lambda is not Hermitian at energy 2.17, difference = 0.0029478657683563014
# Lambda is not Hermitian at energy 2.18, difference = 0.002924166291799216
# Lambda is not Hermitian at energy 2.19, difference = 0.0029007517035909815
# Lambda is not Hermitian at energy 2.2, difference = 0.002877617443137674
# Lambda is not Hermitian at energy 2.21, difference = 0.0028547590398997776
# Lambda is not Hermitian at energy 2.22, difference = 0.002832172111221185
# Lambda is not Hermitian at energy 2.23, difference = 0.002809852360215086
# Lambda is not Hermitian at energy 2.24, difference = 0.00278779557370666
# Lambda is not Hermitian at energy 2.25, difference = 0.0027659976202287643
# Lambda is not Hermitian at energy 2.26, difference = 0.0027444544480723764
# Lambda is not Hermitian at energy 2.27, difference = 0.0027231620833852487
# Lambda is not Hermitian at energy 2.28, difference = 0.0027021166283209943
# Lambda is not Hermitian at energy 2.29, difference = 0.002681314259234496
# Lambda is not Hermitian at energy 2.3, difference = 0.0026607512249248355
# Lambda is not Hermitian at energy 2.31, difference = 0.002640423844919116
# Lambda is not Hermitian at energy 2.32, difference = 0.0026203285078023704
# Lambda is not Hermitian at energy 2.33, difference = 0.0026004616695854436
# Lambda is not Hermitian at energy 2.34, difference = 0.0025808198521140593
# Lambda is not Hermitian at energy 2.35, difference = 0.002561399641515593
# Lambda is not Hermitian at energy 2.36, difference = 0.0025421976866822813
# Lambda is not Hermitian at energy 2.37, difference = 0.0025232106977901123
# Lambda is not Hermitian at energy 2.38, difference = 0.0025044354448510455
# Lambda is not Hermitian at energy 2.39, difference = 0.00248586875629746
# Lambda is not Hermitian at energy 2.4, difference = 0.0024675075175996414
# Lambda is not Hermitian at energy 2.41, difference = 0.002449348669910599
# Lambda is not Hermitian at energy 2.42, difference = 0.002431389208741121
# Lambda is not Hermitian at energy 2.43, difference = 0.002413626182661714
# Lambda is not Hermitian at energy 2.44, difference = 0.00239605669202986
# Lambda is not Hermitian at energy 2.45, difference = 0.0023786778877431243
# Lambda is not Hermitian at energy 2.46, difference = 0.0023614869700142468
# Lambda is not Hermitian at energy 2.47, difference = 0.0023444811871695535
# Lambda is not Hermitian at energy 2.48, difference = 0.0023276578344664143
# Lambda is not Hermitian at energy 2.49, difference = 0.002311014252931433
# Lambda is not Hermitian at energy 2.5, difference = 0.0022945478282164603
# Lambda is not Hermitian at energy 2.51, difference = 0.0022782559894699754
# Lambda is not Hermitian at energy 2.52, difference = 0.0022621362082246837
# Lambda is not Hermitian at energy 2.53, difference = 0.0022461859972983016
# Lambda is not Hermitian at energy 2.54, difference = 0.0022304029097057494
# Lambda is not Hermitian at energy 2.55, difference = 0.002214784537583289
# Lambda is not Hermitian at energy 2.56, difference = 0.0021993285111195234
# Lambda is not Hermitian at energy 2.57, difference = 0.0021840324974942774
# Lambda is not Hermitian at energy 2.58, difference = 0.0021688941998229054
# Lambda is not Hermitian at energy 2.59, difference = 0.0021539113561026006
# Lambda is not Hermitian at energy 2.6, difference = 0.0021390817381609813
# Lambda is not Hermitian at energy 2.61, difference = 0.0021244031506021176
# Lambda is not Hermitian at energy 2.62, difference = 0.0021098734297500888
# Lambda is not Hermitian at energy 2.63, difference = 0.0020954904425853358
# Lambda is not Hermitian at energy 2.64, difference = 0.0020812520856728378
# Lambda is not Hermitian at energy 2.65, difference = 0.002067156284077725
# Lambda is not Hermitian at energy 2.66, difference = 0.002053200990265867
# Lambda is not Hermitian at energy 2.67, difference = 0.0020393841829854553
# Lambda is not Hermitian at energy 2.68, difference = 0.0020257038661259303
# Lambda is not Hermitian at energy 2.69, difference = 0.002012158067550166
# Lambda is not Hermitian at energy 2.7, difference = 0.0019987448378941557
# Lambda is not Hermitian at energy 2.71, difference = 0.001985462249330976
# Lambda is not Hermitian at energy 2.72, difference = 0.001972308394290884
# Lambda is not Hermitian at energy 2.73, difference = 0.0019592813841339267
# Lambda is not Hermitian at energy 2.74, difference = 0.0019463793477649258
# Lambda is not Hermitian at energy 2.75, difference = 0.001933600430186102
# Lambda is not Hermitian at energy 2.76, difference = 0.001920942790976318
# Lambda is not Hermitian at energy 2.77, difference = 0.0019084046026882154
# Lambda is not Hermitian at energy 2.78, difference = 0.001895984049152073
# Lambda is not Hermitian at energy 2.79, difference = 0.0018836793236737812
# Lambda is not Hermitian at energy 2.8, difference = 0.0018714886271138063
# Lambda is not Hermitian at energy 2.81, difference = 0.0018594101658303953
# Lambda is not Hermitian at energy 2.82, difference = 0.0018474421494703375
# Lambda is not Hermitian at energy 2.83, difference = 0.0018355827885866744
# Lambda is not Hermitian at energy 2.84, difference = 0.0018238302920604746
# Lambda is not Hermitian at energy 2.85, difference = 0.0018121828643014046
# Lambda is not Hermitian at energy 2.86, difference = 0.0018006387021967116
# Lambda is not Hermitian at energy 2.87, difference = 0.0017891959917757463
# Lambda is not Hermitian at energy 2.88, difference = 0.001777852904550094
# Lambda is not Hermitian at energy 2.89, difference = 0.0017666075934862305
# Lambda is not Hermitian at energy 2.9, difference = 0.0017554581885587223
# Lambda is not Hermitian at energy 2.91, difference = 0.001744402791825211
# Lambda is not Hermitian at energy 2.92, difference = 0.0017334394719547973
# Lambda is not Hermitian at energy 2.93, difference = 0.0017225662581312445
# Lambda is not Hermitian at energy 2.94, difference = 0.0017117811332388216
# Lambda is not Hermitian at energy 2.95, difference = 0.0017010820262232276
# Lambda is not Hermitian at energy 2.96, difference = 0.0016904668035038382
# Lambda is not Hermitian at energy 2.97, difference = 0.0016799332592889811
# Lambda is not Hermitian at energy 2.98, difference = 0.001669479104623897
# Lambda is not Hermitian at energy 2.99, difference = 0.0016591019549670521
# Lambda is not Hermitian at energy 3.0, difference = 0.00164879931605511
# Lambda is not Hermitian at energy 3.01, difference = 0.0016385685677730863
# Lambda is not Hermitian at energy 3.02, difference = 0.001628406945690445
# Lambda is not Hermitian at energy 3.03, difference = 0.0016183115198580055
# Lambda is not Hermitian at energy 3.04, difference = 0.0016082791703840467
# Lambda is not Hermitian at energy 3.05, difference = 0.001598306559204782
# Lambda is not Hermitian at energy 3.06, difference = 0.0015883900973467852
# Lambda is not Hermitian at energy 3.07, difference = 0.001578525906830547
# Lambda is not Hermitian at energy 3.08, difference = 0.0015687097761755936
# Lambda is not Hermitian at energy 3.09, difference = 0.001558937108240063
# Lambda is not Hermitian at energy 3.1, difference = 0.0015492028588373924
# Lambda is not Hermitian at energy 3.11, difference = 0.001539501464206234
# Lambda is not Hermitian at energy 3.12, difference = 0.0015298267549505268
# Lambda is not Hermitian at energy 3.13, difference = 0.001520171853476566
# Lambda is not Hermitian at energy 3.14, difference = 0.0015105290511988328
# Lambda is not Hermitian at energy 3.15, difference = 0.0015008896608155033
# Lambda is not Hermitian at energy 3.16, difference = 0.001491243837691208
# Lambda is not Hermitian at energy 3.17, difference = 0.0014815803627297509
# Lambda is not Hermitian at energy 3.18, difference = 0.0014718863769529148
# Lambda is not Hermitian at energy 3.19, difference = 0.001462147055106678
# Lambda is not Hermitian at energy 3.2, difference = 0.0014523452017619178
# Lambda is not Hermitian at energy 3.21, difference = 0.0014424607481625204
# Lambda is not Hermitian at energy 3.22, difference = 0.0014324701209771989
# Lambda is not Hermitian at energy 3.23, difference = 0.0014223454443473768
# Lambda is not Hermitian at energy 3.24, difference = 0.0014120535230591205
# Lambda is not Hermitian at energy 3.25, difference = 0.0014015545355956236
# Lambda is not Hermitian at energy 3.26, difference = 0.0013908003387341225
# Lambda is not Hermitian at energy 3.27, difference = 0.0013797322462954311
# Lambda is not Hermitian at energy 3.28, difference = 0.001368278087704586
# Lambda is not Hermitian at energy 3.29, difference = 0.0013563482676290154
# Lambda is not Hermitian at energy 3.3, difference = 0.0013438304210317271
# Lambda is not Hermitian at energy 3.31, difference = 0.0013305820637354794
# Lambda is not Hermitian at energy 3.32, difference = 0.001316420335915979
# Lambda is not Hermitian at energy 3.33, difference = 0.0013011074547142943
# Lambda is not Hermitian at energy 3.34, difference = 0.0012843297104671461
# Lambda is not Hermitian at energy 3.35, difference = 0.0012656665409475885
# Lambda is not Hermitian at energy 3.36, difference = 0.001244543999656195
# Lambda is not Hermitian at energy 3.37, difference = 0.0012201630418902252
# Lambda is not Hermitian at energy 3.38, difference = 0.0011913860138335394
# Lambda is not Hermitian at energy 3.39, difference = 0.0011565515839058666
# Lambda is not Hermitian at energy 3.4, difference = 0.0011131629657670213
# Lambda is not Hermitian at energy 3.41, difference = 0.0010573436481324246
# Lambda is not Hermitian at energy 3.42, difference = 0.0009828516175584769
# Lambda is not Hermitian at energy 3.43, difference = 0.0008792367866767406
# Lambda is not Hermitian at energy 3.44, difference = 0.0007284105358968777
# Lambda is not Hermitian at energy 3.45, difference = 0.000499958765633222
# Lambda is not Hermitian at energy 3.46, difference = 0.00020934832412956953
# Lambda is not Hermitian at energy 3.47, difference = 0.0006814769322772916
# Lambda is not Hermitian at energy 3.48, difference = 0.0018917487528380375
# Lambda is not Hermitian at energy 3.49, difference = 0.003461059591675537
# Lambda is not Hermitian at energy 3.5, difference = 0.003661861465261729
# Lambda is not Hermitian at energy 3.51, difference = 0.002180088696059681
# Lambda is not Hermitian at energy 3.52, difference = 0.000873444773406281
# Lambda is not Hermitian at energy 3.53, difference = 0.00021276075987534086
# Lambda is not Hermitian at energy 3.54, difference = 0.0003966590823597919
# Lambda is not Hermitian at energy 3.55, difference = 0.0006268157615944799
# Lambda is not Hermitian at energy 3.56, difference = 0.0007751203607172949
# Lambda is not Hermitian at energy 3.57, difference = 0.0008722472258212521
# Lambda is not Hermitian at energy 3.58, difference = 0.0009378856681247508
# Lambda is not Hermitian at energy 3.59, difference = 0.0009834460359251097
# Lambda is not Hermitian at energy 3.6, difference = 0.0010157122053590236
# Lambda is not Hermitian at energy 3.61, difference = 0.0010388727093284316
# Lambda is not Hermitian at energy 3.62, difference = 0.001055610011975892
# Lambda is not Hermitian at energy 3.63, difference = 0.0010676996542961263
# Lambda is not Hermitian at energy 3.64, difference = 0.0010763516931274796
# Lambda is not Hermitian at energy 3.65, difference = 0.001082412307231941
# Lambda is not Hermitian at energy 3.66, difference = 0.0010864868331756864
# Lambda is not Hermitian at energy 3.67, difference = 0.0010890171388344885
# Lambda is not Hermitian at energy 3.68, difference = 0.0010903316163928505
# Lambda is not Hermitian at energy 3.69, difference = 0.0010906782816157703
# Lambda is not Hermitian at energy 3.7, difference = 0.001090247175727276
# Lambda is not Hermitian at energy 3.71, difference = 0.0010891858320958617
# Lambda is not Hermitian at energy 3.72, difference = 0.001087610149408932
# Lambda is not Hermitian at energy 3.73, difference = 0.0010856121624025154
# Lambda is not Hermitian at energy 3.74, difference = 0.00108326567949904
# Lambda is not Hermitian at energy 3.75, difference = 0.0010806304296517625
# Lambda is not Hermitian at energy 3.76, difference = 0.0010777551515420926
# Lambda is not Hermitian at energy 3.77, difference = 0.0010746799219450147
# Lambda is not Hermitian at energy 3.78, difference = 0.0010714379297316944
# Lambda is not Hermitian at energy 3.79, difference = 0.0010680568411464949
# Lambda is not Hermitian at energy 3.8, difference = 0.0010645598603688023
# Lambda is not Hermitian at energy 3.81, difference = 0.0010609665605823054
# Lambda is not Hermitian at energy 3.82, difference = 0.0010572935405223805
# Lambda is not Hermitian at energy 3.83, difference = 0.001053554947124555
# Lambda is not Hermitian at energy 3.84, difference = 0.0010497628945649667
# Lambda is not Hermitian at energy 3.85, difference = 0.0010459278025058863
# Lambda is not Hermitian at energy 3.86, difference = 0.0010420586708540297
# Lambda is not Hermitian at energy 3.87, difference = 0.001038163304295665
# Lambda is not Hermitian at energy 3.88, difference = 0.0010342484968326405
# Lambda is not Hermitian at energy 3.89, difference = 0.0010303201842575029
# Lambda is not Hermitian at energy 3.9, difference = 0.001026383570791578
# Lambda is not Hermitian at energy 3.91, difference = 0.001022443234770064
# Lambda is not Hermitian at energy 3.92, difference = 0.0010185032172597478
# Lambda is not Hermitian at energy 3.93, difference = 0.0010145670966888365
# Lambda is not Hermitian at energy 3.94, difference = 0.00101063805197329
# Lambda is not Hermitian at energy 3.95, difference = 0.001006718916130026
# Lambda is not Hermitian at energy 3.96, difference = 0.0010028122219902437
# Lambda is not Hermitian at energy 3.97, difference = 0.0009989202413296227
# Lambda is not Hermitian at energy 3.98, difference = 0.000995045018488085
# Lambda is not Hermitian at energy 3.99, difference = 0.0009911883993623995
# Lambda is not Hermitian at energy 4.0, difference = 0.0009873520564964268
