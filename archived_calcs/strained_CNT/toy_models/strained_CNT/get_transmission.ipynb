# %%
import matplotlib.pyplot as plt
import numpy as np
from qtpyt.tools import expand_coupling
from ase.build import nanotube
from ase.neighborlist import NeighborList
from qtpyt.base.greenfunction import GreenFunction
from qtpyt.parallel.egrid import GridDesc

# %%
def build_device_structure(n=6, m=0, N_L=3, N_M=4, N_R=3, bond=1.42, direction='x', tag_regions=True):
    """
    Build a CNT device using ASE nanotube with clear region tagging.

    Args:
        n, m: Chiral indices.
        N_L, N_M, N_R: Unit cells in left, middle, right.
        bond: C–C bond length.
        direction: Axis of tube ('x', 'y', or 'z').
        tag_regions: Whether to tag atoms by region (L=1, M=2, R=3).

    Returns:
        ase.Atoms with 'region' tags if enabled.
    """
    total_cells = N_L + N_M + N_R
    atoms = nanotube(n=n, m=m, length=total_cells, bond=bond, verbose=False)


    if direction == 'x':
        atoms.rotate('z', 'x', rotate_cell=True, center='COP')
        axis = 0
    elif direction == 'y':
        atoms.rotate('z', 'y', rotate_cell=True, center='COP')
        axis = 1
    elif direction == 'z':
        axis = 2
    else:
        raise ValueError("Direction must be 'x', 'y', or 'z'")


    positions = atoms.get_positions()
    coord = positions[:, axis]
    x_min, x_max = coord.min(), coord.max()
    total_len = x_max - x_min
    uc_len = total_len / total_cells


    x_L = x_min + N_L * uc_len
    x_M = x_L + N_M * uc_len

    if tag_regions:
        regions = []
        for x in coord:
            if x < x_L:
                regions.append(1)
            elif x < x_M:
                regions.append(2)
            else:
                regions.append(3)
        atoms.set_array('region', np.array(regions, dtype=int))

    atoms.set_pbc((1, 0, 0))
    return atoms

def apply_strain(atoms, strain_percent, axis=0, copy=True):
    """
    Apply uniaxial strain only to region 2 (middle) of the CNT structure,
    anchoring the left boundary and shifting region 3 to preserve bond lengths.

    Parameters
    ----------
    atoms : ase.Atoms
        Atomic structure with a 'region' array.
    strain_percent : float
        Strain percentage to apply to region 2.
    axis : int
        Axis along which to apply strain (default: 0 for x-axis).
    copy : bool
        If True (default), operates on a copy of `atoms`. If False, modifies `atoms` in-place.

    Returns
    -------
    ase.Atoms
        Strained ASE Atoms object.

    Notes
    -----
    Region 2 is stretched from its left boundary.
    Region 3 is rigidly shifted to maintain M–R bond lengths.
    Region 1 is left unmodified.
    """
    if copy:
        atoms = atoms.copy()

    if 'region' not in atoms.arrays:
        raise ValueError("Atoms object must have 'region' array to apply region-specific strain.")

    positions = atoms.get_positions()
    regions = atoms.get_array('region')

    strain = 1 + strain_percent / 100.0
    coord = positions[:, axis]
    mask_M = regions == 2
    mask_R = regions == 3


    x_M_min = coord[mask_M].min()
    x_M_max = coord[mask_M].max()
    original_length = x_M_max - x_M_min


    strained_positions = positions.copy()
    strained_positions[mask_M, axis] = x_M_min + strain * (positions[mask_M, axis] - x_M_min)


    delta = (strain - 1.0) * original_length
    strained_positions[mask_R, axis] += delta

    atoms.set_positions(strained_positions)
    return atoms

def build_real_space_device_hamiltonian(
    atoms,
    pairs,
    bond=1.42,
    q_pi=3.1451,
    q_sigma=7.428,
    V_pi=-2.7,
    V_sigma=0.48,
    angle_dependence=False,
    angles=None,
    degrees=True
):
    """
    Construct real-space Hamiltonian for a CNT device using known neighbor pairs.

    Parameters
    ----------
    atoms : ase.Atoms
        CNT device structure.
    pairs : list of tuples
        Precomputed nearest-neighbor pairs.
    bond : float
        Ideal bond length.
    beta : float
        Decay factor for hopping integral.
    t0 : float
        Hopping at ideal bond length.
    angle_dependence : bool
        Whether to include cos(theta) dependence based on precomputed angles.
    angles : list of float, optional
        List of angles for each pair in `pairs` (in degrees by default).
    degrees : bool
        Whether the provided angles are in degrees (default: True).

    Returns
    -------
    H : np.ndarray
        Hamiltonian matrix (N_atoms x N_atoms).
    """
    N_atoms = len(atoms)
    positions = atoms.get_positions()
    cell = atoms.get_cell()
    H = np.zeros((N_atoms, N_atoms), dtype=float)

    if angle_dependence and angles is None:
        raise ValueError("angles must be provided when angle_dependence=True")

    for idx, (i, j, offset) in enumerate(pairs):
        ri = positions[i]
        rj = positions[j] + np.dot(offset, cell)
        dist = np.linalg.norm(ri - rj)

        if angle_dependence:
            angle = angles[idx]
            if degrees:
                cos_theta = np.cos(np.radians(angle))
            else:
                cos_theta = np.cos(angle)
        else:
            cos_theta = 1.0

        hopping = V_pi * cos_theta * np.exp(-q_pi * (dist / bond - 1))

        H[i, j] = hopping
        H[j, i] = hopping

    return H

def get_nearest_neighbor_pairs(atoms, neighbor_cutoff=1.42, bond=1.42, atol=0.1):
    """
    Compute nearest-neighbor atom pairs using a distance cutoff and bond tolerance.

    Args:
        atoms (ase.Atoms): The atomic structure.
        neighbor_cutoff (float): Distance threshold for neighbors.
        bond (float): Ideal bond length.
        atol (float): Absolute tolerance for bond length deviation.

    Returns:
        List[Tuple[int, int, Tuple[int, int, int]]]: Valid neighbor pairs and cell offsets.
    """
    N = len(atoms)
    cutoffs = [neighbor_cutoff] * N
    nl = NeighborList(cutoffs, self_interaction=False, bothways=True)
    nl.update(atoms)

    positions = atoms.get_positions()
    cell = atoms.get_cell()

    pairs = set()
    for i in range(N):
        for j, offset in zip(*nl.get_neighbors(i)):
            if j > i:
                ri = positions[i]
                rj = positions[j] + np.dot(offset, cell)
                dist = np.linalg.norm(ri - rj)
                if np.abs(dist - bond) <= atol:
                    pairs.add((i, j, tuple(offset)))
    return list(pairs)

# %%
# Parameters
n, m = 6, 0
ncells = 2
bond = 1.42
onsite = 0.0  # eV
eta = 1e-5
first_neighbor_hopping = -2.7  # eV
q_pi = 0.0
neighbor_cutoff = 1.42  # Å for nearest neighbors
d0 = bond
energies = np.linspace(-3, 3, 100)
self_energy = np.load('lead_self_energy.npy',allow_pickle=True)

# %%
device = build_device_structure(n=6, m=0, N_L=1, N_M=4, N_R=1, direction='x')
pairs = get_nearest_neighbor_pairs(device, neighbor_cutoff=neighbor_cutoff)

# %%
H_device= build_real_space_device_hamiltonian(device, pairs, bond=bond, q_pi=q_pi, V_pi=first_neighbor_hopping)
S_device = np.eye(H_device.shape[0])
plt.imshow(H_device, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title('Real-space Hamiltonian')
plt.show()

# %%
expand_coupling(self_energy[0], len(H_device[0]))
expand_coupling(self_energy[1], len(H_device[0]), id='right')

# slice(None) means that we've already expanded the leads to the scattering region
gf = GreenFunction(H_device, S_device, selfenergies=[(slice(None),self_energy[0]),(slice(None),self_energy[1])], eta=eta)

gd = GridDesc(energies, 1)
T = np.empty(gd.energies.size)

for e, energy in enumerate(gd.energies):
    T[e] = gf.get_transmission(energy, ferretti=False)

T = gd.gather_energies(T)

# %%
plt.figure(figsize=(10, 5))
plt.plot(energies, T)
plt.xlabel("Energy (eV)")
plt.ylabel("Transmission")
plt.title("Transmission vs Energy")
plt.xlim(-3, 3)
# plt.ylim(0, 1)
plt.grid()
plt.show()

# %% [markdown]
# ### Strained

# %%
q_pi = 3.1451 # Value from WannierTools, https://pubs.acs.org/doi/10.1021/acs.nanolett.9b05117
strained_device = apply_strain(device, 4.0, axis=0)
H_strained_device = build_real_space_device_hamiltonian(strained_device, pairs, bond=bond, q_pi=q_pi, V_pi=first_neighbor_hopping)
S_strained_device = np.eye(H_strained_device.shape[0])
plt.imshow(H_strained_device, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title('Strained Real-space Hamiltonian')
plt.show()

# %%
strain_percentages = np.array([0, 2, 4, 6, 8, 10])
plt.figure(figsize=(10, 5))
for strain in strain_percentages:
    strained_device = apply_strain(device, strain, axis=0)
    H_strained_device = build_real_space_device_hamiltonian(strained_device, pairs, bond=bond, q_pi=q_pi, V_pi=first_neighbor_hopping)
    S_strained_device = np.eye(H_strained_device.shape[0])

    gf = GreenFunction(H_strained_device, S_strained_device, selfenergies=[(slice(None),self_energy[0]),(slice(None),self_energy[1])], eta=eta)

    gd = GridDesc(energies, 1)
    T = np.empty(gd.energies.size)

    for e, energy in enumerate(gd.energies):
        T[e] = gf.get_transmission(energy, ferretti=False)

    T = gd.gather_energies(T)
    plt.plot(energies, T, label=f"Strain: {strain}%")
plt.xlabel("Energy (eV)")
plt.ylabel("Transmission")
plt.title("Transmission vs Energy")
plt.xlim(-3, 3)
# plt.ylim(0, 1)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Increase number of unit cell that are strained

# %%
N_Ms = [2, 4, 8]
strain = 4.0
plt.figure(figsize=(10, 5))
q_pi = 3.1451
for N_M in N_Ms:
    device = build_device_structure(n=6, m=0, N_L=1, N_M=N_M, N_R=1, direction='x')
    pairs = get_nearest_neighbor_pairs(device, neighbor_cutoff=neighbor_cutoff)

    strained_device = apply_strain(device, strain, axis=0)
    H_strained_device = build_real_space_device_hamiltonian(strained_device, pairs, bond=bond, q_pi=q_pi, V_pi=first_neighbor_hopping)
    S_strained_device = np.eye(H_strained_device.shape[0])

    self_energy = np.load('lead_self_energy.npy',allow_pickle=True)
    expand_coupling(self_energy[0], len(H_strained_device[0]))
    expand_coupling(self_energy[1], len(H_strained_device[0]), id='right')

    gf = GreenFunction(H_strained_device, S_strained_device, selfenergies=[(slice(None),self_energy[0]),(slice(None),self_energy[1])], eta=eta)


    gd = GridDesc(energies, 1)
    T = np.empty(gd.energies.size)

    for e, energy in enumerate(gd.energies):
        T[e] = gf.get_transmission(energy, ferretti=False)

    T = gd.gather_energies(T)
    plt.plot(energies, T, label=f"N_M: {N_M}")

plt.xlabel("Energy (eV)")
plt.ylabel("Transmission")
plt.title("Transmission vs Energy of Strained CNT")
plt.xlim(-3, 3)
# plt.ylim(0, 1)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Increase the number of unstrained unit cells that serve as connection to the leads
# - Fix the number of strained unit cells to 10 and the strain to 4 %

# %%
N_M = 10
N_Ls = [1, 2, 5]
strain = 4.0
plt.figure(figsize=(10, 5))

for N_L in N_Ls:
    device = build_device_structure(n=6, m=0, N_L=N_L, N_M=N_M, N_R=N_L, direction='x')
    pairs = get_nearest_neighbor_pairs(device, neighbor_cutoff=neighbor_cutoff)

    strained_device = apply_strain(device, strain, axis=0)
    H_strained_device = build_real_space_device_hamiltonian(strained_device, pairs, bond=bond, q_pi=q_pi, V_pi=first_neighbor_hopping)
    S_strained_device = np.eye(H_strained_device.shape[0])

    self_energy = np.load('lead_self_energy.npy',allow_pickle=True)
    expand_coupling(self_energy[0], len(H_strained_device[0]))
    expand_coupling(self_energy[1], len(H_strained_device[0]), id='right')

    gf = GreenFunction(H_strained_device, S_strained_device, selfenergies=[(slice(None),self_energy[0]),(slice(None),self_energy[1])], eta=eta)


    gd = GridDesc(energies, 1)
    T = np.empty(gd.energies.size)

    for e, energy in enumerate(gd.energies):
        T[e] = gf.get_transmission(energy, ferretti=False)

    T = gd.gather_energies(T)
    plt.plot(energies, T, label=f"N_L, N_R: {N_L}")

plt.xlabel("Energy (eV)")
plt.ylabel("Transmission")
plt.title("Transmission vs Energy of Strained CNT")
plt.xlim(-3, 3)
# plt.ylim(0, 1)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Effect of curvature
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
import numpy as np
from typing import List, Tuple
import plotly.graph_objects as go

def compute_pz_angles_plane_normals(
    atoms: 'ase.Atoms',
    pairs: List[Tuple[int, int, Tuple[int, int, int]]],
    degrees: bool = True
) -> Tuple[List[float], np.ndarray]:
    cell = atoms.get_cell()
    positions = atoms.get_positions()
    num_atoms = len(atoms)
    print(f"Number of atoms in extended device: {num_atoms}")
    centroid = np.mean(positions, axis=0)

    neighbor_dict = {i: [] for i in range(num_atoms)}
    for i, j, offset in pairs:
        if tuple(offset) == (0,0,0):
            neighbor_dict[i].append((j, offset))
            neighbor_dict[j].append((i, tuple(-np.array(offset))))

    pz_dirs = np.zeros((num_atoms, 3))
    for i in range(num_atoms):
        neighbors = neighbor_dict[i]
        if len(neighbors) < 3:
            print(f" Atom {i} has only {len(neighbors)} neighbors in the extended device.")
            continue

        V = []
        for j, offset in neighbors:
            V.append(positions[j] + np.dot(offset, cell) - positions[i])

        V1 = V[0]
        V2 = V[1]
        V3 = V[2]
        V21 = V2 - V1
        V31 = V3 - V1
        cross = np.cross(V21, V31)
        norm = np.linalg.norm(cross)
        if norm > 0:
            normal = cross / norm
            radial = positions[i].copy() - centroid
            radial[0] = 0.0
            if np.dot(normal, radial) < 0:
                normal = -normal
            pz_dirs[i] = normal
        else:
            print(f" Atom {i} has collinear neighbors, cannot compute pz direction.")

    angles = []
    for i, j, _ in pairs:
        ni = pz_dirs[i]
        nj = pz_dirs[j]
        dot = np.clip(np.dot(ni, nj), -1.0, 1.0)
        angle = np.arccos(dot)
        if degrees:
            angle = np.degrees(angle)
        angles.append(angle)

    return angles, pz_dirs

def compute_pz_dirs_and_angles(
    n: int,
    m: int,
    N_L: int,
    N_M: int,
    N_R: int,
    bond: float,
    direction: str,
    neighbor_cutoff: float,
    pairs_original: List[Tuple[int, int, Tuple[int, int, int]]],
    degrees: bool = True,
    strain: float = 0.0
) -> Tuple[List[float], np.ndarray]:
    device_extended = build_device_structure(n=n, m=m, N_L=N_L+1, N_M=N_M, N_R=N_R+1, bond=bond, direction=direction)
    device_extended_strained = apply_strain(device_extended, strain, axis=0, copy=True)
    neighbor_cutoff = neighbor_cutoff + strain * bond / 100.0
    pairs_extended = get_nearest_neighbor_pairs(device_extended_strained, neighbor_cutoff=neighbor_cutoff)
    angles_ext, pz_dirs_ext = compute_pz_angles_plane_normals(device_extended_strained, pairs_extended, degrees=degrees)

    n_atoms_unit = build_device_structure(n=n, m=m, N_L=0, N_M=1, N_R=0, bond=bond, direction=direction).get_positions().shape[0]
    start_idx = (N_L ) * n_atoms_unit
    end_idx = start_idx + (N_L + N_M + N_R ) * n_atoms_unit
    pz_dirs = pz_dirs_ext[start_idx:end_idx]

    original_indices = set(range(start_idx, end_idx))
    pair_to_angle = {}
    for (i, j, _), angle in zip(pairs_extended, angles_ext):
        if i in original_indices and j in original_indices:
            pair_to_angle[(i - start_idx, j - start_idx)] = angle
            pair_to_angle[(j - start_idx, i - start_idx)] = angle

    angles = []
    for i, j, _ in pairs_original:
        angle = pair_to_angle.get((i, j))
        if angle is None:
            print(f" Warning: No angle found for pair ({i}, {j}), setting angle = 0.")
            angle = 0.0
        angles.append(angle)

    return angles, pz_dirs

def plot_pz_normals_plotly(atoms, pz_dirs, pairs, scale=0.5):
    positions = atoms.get_positions()
    pz_dirs = np.array(pz_dirs)


    atom_trace = go.Scatter3d(
        x=positions[:, 0],
        y=positions[:, 1],
        z=positions[:, 2],
        mode='markers',
        marker=dict(size=5, color='black'),
        showlegend=False
    )


    arrow_traces = []
    for pos, dir_vec in zip(positions, pz_dirs):
        arrow = go.Scatter3d(
            x=[pos[0], pos[0] + scale * dir_vec[0]],
            y=[pos[1], pos[1] + scale * dir_vec[1]],
            z=[pos[2], pos[2] + scale * dir_vec[2]],
            mode='lines',
            line=dict(color='red', width=3),
            showlegend=False
        )
        arrow_traces.append(arrow)


    bond_traces = []
    cell = atoms.get_cell()
    for i, j, offset in pairs:
        ri = positions[i]
        rj = positions[j] + np.dot(offset, cell)
        bond = go.Scatter3d(
            x=[ri[0], rj[0]],
            y=[ri[1], rj[1]],
            z=[ri[2], rj[2]],
            mode='lines',
            line=dict(color='gray', width=3),
            showlegend=False
        )
        bond_traces.append(bond)


    fig = go.Figure(data=[atom_trace] + arrow_traces + bond_traces)

    fig.update_layout(
        scene=dict(
            xaxis_title='X',
            yaxis_title='Y',
            zaxis_title='Z',
            aspectmode='data',
        ),
        title='CNT Atoms, pz Orbitals, and Bonds',
        margin=dict(l=0, r=0, b=0, t=30),
        showlegend=False
    )

    fig.show()

# %%
n,m = 6, 0
N_L, N_M, N_R = 1, 2, 1
bond = 1.42

device = build_device_structure(n=n, m=m, N_L=N_L, N_M=N_M, N_R=N_R, bond=bond, direction='x')
pairs = get_nearest_neighbor_pairs(
        device,
        neighbor_cutoff=1.43)


angles, pz_dirs = compute_pz_dirs_and_angles(
    n=n,
    m=m,
    N_L=N_L,
    N_M=N_M,
    N_R=N_R,
    bond=bond,
    direction='x',
    neighbor_cutoff=1.43,
    pairs_original=pairs,
)
plt.plot(angles, marker='o', linestyle='None')
# Out:
# Number of atoms in extended device: 144
#  Atom 0 has only 1 neighbors in the extended device.
#  Atom 4 has only 1 neighbors in the extended device.
#  Atom 8 has only 1 neighbors in the extended device.
#  Atom 12 has only 1 neighbors in the extended device.
#  Atom 16 has only 1 neighbors in the extended device.
#  Atom 20 has only 1 neighbors in the extended device.
#  Atom 121 has only 1 neighbors in the extended device.
#  Atom 125 has only 1 neighbors in the extended device.
#  Atom 129 has only 1 neighbors in the extended device.
#  Atom 133 has only 1 neighbors in the extended device.
#  Atom 137 has only 1 neighbors in the extended device.
#  Atom 141 has only 1 neighbors in the extended device.

# %%
plot_pz_normals_plotly(device, pz_dirs, pairs, scale=1.5)

# %%
H_device_theta = build_real_space_device_hamiltonian(
    device, pairs, bond=bond, q_pi=q_pi, V_pi=first_neighbor_hopping, angle_dependence=True, angles=angles, degrees=True
)
plt.imshow(H_device_theta, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title('Real-space Hamiltonian with Angle Dependence')
plt.show()

# %%
N_L, N_M, N_R = 1, 4, 1
plt.figure(figsize=(10, 5))
n,m = 6, 0
bond = 1.42
strain_percentages = np.array([0, 2, 4, 6, 8, 10])

for strain in strain_percentages:
    device = build_device_structure(n=n, m=m, N_L=N_L, N_M=N_M, N_R=N_R, direction='x')
    pairs = get_nearest_neighbor_pairs(device, neighbor_cutoff=neighbor_cutoff)
    strained_device = apply_strain(device, strain, axis=0)

    angles, pz_dirs = compute_pz_dirs_and_angles(
        n=n,
        m=m,
        N_L=N_L,
        N_M=N_M,
        N_R=N_R,
        bond=bond,
        direction='x',
        neighbor_cutoff=neighbor_cutoff,
        pairs_original=pairs,
        strain=strain
    )

    self_energy = np.load('lead_self_energy_with_angles.npy', allow_pickle=True)
    expand_coupling(self_energy[0], len(strained_device))
    expand_coupling(self_energy[1], len(strained_device), id='right')

    H_angle = build_real_space_device_hamiltonian(
        strained_device, pairs, bond=bond, q_pi=q_pi, V_pi=first_neighbor_hopping,
        angle_dependence=True, angles=angles, degrees=True
    )

    S_strained_device = np.eye(H_angle.shape[0])

    gf_angle = GreenFunction(H_angle, S_strained_device, selfenergies=[(slice(None), self_energy[0]), (slice(None), self_energy[1])], eta=eta)
    T_angle = np.empty(energies.size)
    for e, energy in enumerate(energies):
        T_angle[e] = gf_angle.get_transmission(energy, ferretti=False)

    plt.plot(energies, T_angle, label=f"Strain: {strain}%")

plt.xlabel("Energy (eV)")
plt.ylabel("Transmission")
plt.title("Transmission vs Energy of Strained CNT")
plt.xlim(-3, 3)
plt.legend()
plt.grid()
plt.show()
# Out:
# Number of atoms in extended device: 192
#  Atom 0 has only 1 neighbors in the extended device.
#  Atom 4 has only 1 neighbors in the extended device.
#  Atom 8 has only 1 neighbors in the extended device.
#  Atom 12 has only 1 neighbors in the extended device.
#  Atom 16 has only 1 neighbors in the extended device.
#  Atom 20 has only 1 neighbors in the extended device.
#  Atom 169 has only 1 neighbors in the extended device.
#  Atom 173 has only 1 neighbors in the extended device.
#  Atom 177 has only 1 neighbors in the extended device.
#  Atom 181 has only 1 neighbors in the extended device.
#  Atom 185 has only 1 neighbors in the extended device.
#  Atom 189 has only 1 neighbors in the extended device.
# Number of atoms in extended device: 192
#  Atom 0 has only 1 neighbors in the extended device.
#  Atom 4 has only 1 neighbors in the extended device.
#  Atom 8 has only 1 neighbors in the extended device.
#  Atom 12 has only 1 neighbors in the extended device.
#  Atom 16 has only 1 neighbors in the extended device.
#  Atom 20 has only 1 neighbors in the extended device.
#  Atom 169 has only 1 neighbors in the extended device.
#  Atom 173 has only 1 neighbors in the extended device.
#  Atom 177 has only 1 neighbors in the extended device.
#  Atom 181 has only 1 neighbors in the extended device.
#  Atom 185 has only 1 neighbors in the extended device.
#  Atom 189 has only 1 neighbors in the extended device.
# Number of atoms in extended device: 192
#  Atom 0 has only 1 neighbors in the extended device.
#  Atom 4 has only 1 neighbors in the extended device.
#  Atom 8 has only 1 neighbors in the extended device.
#  Atom 12 has only 1 neighbors in the extended device.
#  Atom 16 has only 1 neighbors in the extended device.
#  Atom 20 has only 1 neighbors in the extended device.
#  Atom 169 has only 1 neighbors in the extended device.
#  Atom 173 has only 1 neighbors in the extended device.
#  Atom 177 has only 1 neighbors in the extended device.
#  Atom 181 has only 1 neighbors in the extended device.
#  Atom 185 has only 1 neighbors in the extended device.
#  Atom 189 has only 1 neighbors in the extended device.
# Number of atoms in extended device: 192
#  Atom 0 has only 1 neighbors in the extended device.
#  Atom 4 has only 1 neighbors in the extended device.
#  Atom 8 has only 1 neighbors in the extended device.
#  Atom 12 has only 1 neighbors in the extended device.
#  Atom 16 has only 1 neighbors in the extended device.
#  Atom 20 has only 1 neighbors in the extended device.
#  Atom 169 has only 1 neighbors in the extended device.
#  Atom 173 has only 1 neighbors in the extended device.
#  Atom 177 has only 1 neighbors in the extended device.
#  Atom 181 has only 1 neighbors in the extended device.
#  Atom 185 has only 1 neighbors in the extended device.
#  Atom 189 has only 1 neighbors in the extended device.
# Number of atoms in extended device: 192
#  Atom 0 has only 1 neighbors in the extended device.
#  Atom 4 has only 1 neighbors in the extended device.
#  Atom 8 has only 1 neighbors in the extended device.
#  Atom 12 has only 1 neighbors in the extended device.
#  Atom 16 has only 1 neighbors in the extended device.
#  Atom 20 has only 1 neighbors in the extended device.
#  Atom 48 has only 2 neighbors in the extended device.
#  Atom 49 has only 2 neighbors in the extended device.
#  Atom 50 has only 2 neighbors in the extended device.
#  Atom 51 has only 2 neighbors in the extended device.
#  Atom 52 has only 2 neighbors in the extended device.
#  Atom 53 has only 2 neighbors in the extended device.
#  Atom 54 has only 2 neighbors in the extended device.
#  Atom 55 has only 2 neighbors in the extended device.
#  Atom 56 has only 2 neighbors in the extended device.
#  Atom 57 has only 2 neighbors in the extended device.
#  Atom 58 has only 2 neighbors in the extended device.
#  Atom 59 has only 2 neighbors in the extended device.
#  Atom 60 has only 2 neighbors in the extended device.
#  Atom 61 has only 2 neighbors in the extended device.
#  Atom 62 has only 2 neighbors in the extended device.
#  Atom 63 has only 2 neighbors in the extended device.
#  Atom 64 has only 2 neighbors in the extended device.
#  Atom 65 has only 2 neighbors in the extended device.
#  Atom 66 has only 2 neighbors in the extended device.
#  Atom 67 has only 2 neighbors in the extended device.
#  Atom 68 has only 2 neighbors in the extended device.
#  Atom 69 has only 2 neighbors in the extended device.
#  Atom 70 has only 2 neighbors in the extended device.
#  Atom 71 has only 2 neighbors in the extended device.
#  Atom 72 has only 2 neighbors in the extended device.
#  Atom 73 has only 2 neighbors in the extended device.
#  Atom 74 has only 2 neighbors in the extended device.
#  Atom 75 has only 2 neighbors in the extended device.
#  Atom 76 has only 2 neighbors in the extended device.
#  Atom 77 has only 2 neighbors in the extended device.
#  Atom 78 has only 2 neighbors in the extended device.
#  Atom 79 has only 2 neighbors in the extended device.
#  Atom 80 has only 2 neighbors in the extended device.
#  Atom 81 has only 2 neighbors in the extended device.
#  Atom 82 has only 2 neighbors in the extended device.
#  Atom 83 has only 2 neighbors in the extended device.
#  Atom 84 has only 2 neighbors in the extended device.
#  Atom 85 has only 2 neighbors in the extended device.
#  Atom 86 has only 2 neighbors in the extended device.
#  Atom 87 has only 2 neighbors in the extended device.
#  Atom 88 has only 2 neighbors in the extended device.
#  Atom 89 has only 2 neighbors in the extended device.
#  Atom 90 has only 2 neighbors in the extended device.
#  Atom 91 has only 2 neighbors in the extended device.
#  Atom 92 has only 2 neighbors in the extended device.
#  Atom 93 has only 2 neighbors in the extended device.
#  Atom 94 has only 2 neighbors in the extended device.
#  Atom 95 has only 2 neighbors in the extended device.
#  Atom 96 has only 2 neighbors in the extended device.
#  Atom 97 has only 2 neighbors in the extended device.
#  Atom 98 has only 2 neighbors in the extended device.
#  Atom 99 has only 2 neighbors in the extended device.
#  Atom 100 has only 2 neighbors in the extended device.
#  Atom 101 has only 2 neighbors in the extended device.
#  Atom 102 has only 2 neighbors in the extended device.
#  Atom 103 has only 2 neighbors in the extended device.
#  Atom 104 has only 2 neighbors in the extended device.
#  Atom 105 has only 2 neighbors in the extended device.
#  Atom 106 has only 2 neighbors in the extended device.
#  Atom 107 has only 2 neighbors in the extended device.
#  Atom 108 has only 2 neighbors in the extended device.
#  Atom 109 has only 2 neighbors in the extended device.
#  Atom 110 has only 2 neighbors in the extended device.
#  Atom 111 has only 2 neighbors in the extended device.
#  Atom 112 has only 2 neighbors in the extended device.
#  Atom 113 has only 2 neighbors in the extended device.
#  Atom 114 has only 2 neighbors in the extended device.
#  Atom 115 has only 2 neighbors in the extended device.
#  Atom 116 has only 2 neighbors in the extended device.
#  Atom 117 has only 2 neighbors in the extended device.
#  Atom 118 has only 2 neighbors in the extended device.
#  Atom 119 has only 2 neighbors in the extended device.
#  Atom 120 has only 2 neighbors in the extended device.
#  Atom 121 has only 2 neighbors in the extended device.
#  Atom 122 has only 2 neighbors in the extended device.
#  Atom 123 has only 2 neighbors in the extended device.
#  Atom 124 has only 2 neighbors in the extended device.
#  Atom 125 has only 2 neighbors in the extended device.
#  Atom 126 has only 2 neighbors in the extended device.
#  Atom 127 has only 2 neighbors in the extended device.
#  Atom 128 has only 2 neighbors in the extended device.
#  Atom 129 has only 2 neighbors in the extended device.
#  Atom 130 has only 2 neighbors in the extended device.
#  Atom 131 has only 2 neighbors in the extended device.
#  Atom 132 has only 2 neighbors in the extended device.
#  Atom 133 has only 2 neighbors in the extended device.
#  Atom 134 has only 2 neighbors in the extended device.
#  Atom 135 has only 2 neighbors in the extended device.
#  Atom 136 has only 2 neighbors in the extended device.
#  Atom 137 has only 2 neighbors in the extended device.
#  Atom 138 has only 2 neighbors in the extended device.
#  Atom 139 has only 2 neighbors in the extended device.
#  Atom 140 has only 2 neighbors in the extended device.
#  Atom 141 has only 2 neighbors in the extended device.
#  Atom 142 has only 2 neighbors in the extended device.
#  Atom 143 has only 2 neighbors in the extended device.
#  Atom 169 has only 1 neighbors in the extended device.
#  Atom 173 has only 1 neighbors in the extended device.
#  Atom 177 has only 1 neighbors in the extended device.
#  Atom 181 has only 1 neighbors in the extended device.
#  Atom 185 has only 1 neighbors in the extended device.
#  Atom 189 has only 1 neighbors in the extended device.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
# Number of atoms in extended device: 192
#  Atom 0 has only 1 neighbors in the extended device.
#  Atom 4 has only 1 neighbors in the extended device.
#  Atom 8 has only 1 neighbors in the extended device.
#  Atom 12 has only 1 neighbors in the extended device.
#  Atom 16 has only 1 neighbors in the extended device.
#  Atom 20 has only 1 neighbors in the extended device.
#  Atom 48 has only 2 neighbors in the extended device.
#  Atom 49 has only 2 neighbors in the extended device.
#  Atom 50 has only 2 neighbors in the extended device.
#  Atom 51 has only 2 neighbors in the extended device.
#  Atom 52 has only 2 neighbors in the extended device.
#  Atom 53 has only 2 neighbors in the extended device.
#  Atom 54 has only 2 neighbors in the extended device.
#  Atom 55 has only 2 neighbors in the extended device.
#  Atom 56 has only 2 neighbors in the extended device.
#  Atom 57 has only 2 neighbors in the extended device.
#  Atom 58 has only 2 neighbors in the extended device.
#  Atom 59 has only 2 neighbors in the extended device.
#  Atom 60 has only 2 neighbors in the extended device.
#  Atom 61 has only 2 neighbors in the extended device.
#  Atom 62 has only 2 neighbors in the extended device.
#  Atom 63 has only 2 neighbors in the extended device.
#  Atom 64 has only 2 neighbors in the extended device.
#  Atom 65 has only 2 neighbors in the extended device.
#  Atom 66 has only 2 neighbors in the extended device.
#  Atom 67 has only 2 neighbors in the extended device.
#  Atom 68 has only 2 neighbors in the extended device.
#  Atom 69 has only 2 neighbors in the extended device.
#  Atom 70 has only 2 neighbors in the extended device.
#  Atom 71 has only 2 neighbors in the extended device.
#  Atom 72 has only 2 neighbors in the extended device.
#  Atom 73 has only 2 neighbors in the extended device.
#  Atom 74 has only 2 neighbors in the extended device.
#  Atom 75 has only 2 neighbors in the extended device.
#  Atom 76 has only 2 neighbors in the extended device.
#  Atom 77 has only 2 neighbors in the extended device.
#  Atom 78 has only 2 neighbors in the extended device.
#  Atom 79 has only 2 neighbors in the extended device.
#  Atom 80 has only 2 neighbors in the extended device.
#  Atom 81 has only 2 neighbors in the extended device.
#  Atom 82 has only 2 neighbors in the extended device.
#  Atom 83 has only 2 neighbors in the extended device.
#  Atom 84 has only 2 neighbors in the extended device.
#  Atom 85 has only 2 neighbors in the extended device.
#  Atom 86 has only 2 neighbors in the extended device.
#  Atom 87 has only 2 neighbors in the extended device.
#  Atom 88 has only 2 neighbors in the extended device.
#  Atom 89 has only 2 neighbors in the extended device.
#  Atom 90 has only 2 neighbors in the extended device.
#  Atom 91 has only 2 neighbors in the extended device.
#  Atom 92 has only 2 neighbors in the extended device.
#  Atom 93 has only 2 neighbors in the extended device.
#  Atom 94 has only 2 neighbors in the extended device.
#  Atom 95 has only 2 neighbors in the extended device.
#  Atom 96 has only 2 neighbors in the extended device.
#  Atom 97 has only 2 neighbors in the extended device.
#  Atom 98 has only 2 neighbors in the extended device.
#  Atom 99 has only 2 neighbors in the extended device.
#  Atom 100 has only 2 neighbors in the extended device.
#  Atom 101 has only 2 neighbors in the extended device.
#  Atom 102 has only 2 neighbors in the extended device.
#  Atom 103 has only 2 neighbors in the extended device.
#  Atom 104 has only 2 neighbors in the extended device.
#  Atom 105 has only 2 neighbors in the extended device.
#  Atom 106 has only 2 neighbors in the extended device.
#  Atom 107 has only 2 neighbors in the extended device.
#  Atom 108 has only 2 neighbors in the extended device.
#  Atom 109 has only 2 neighbors in the extended device.
#  Atom 110 has only 2 neighbors in the extended device.
#  Atom 111 has only 2 neighbors in the extended device.
#  Atom 112 has only 2 neighbors in the extended device.
#  Atom 113 has only 2 neighbors in the extended device.
#  Atom 114 has only 2 neighbors in the extended device.
#  Atom 115 has only 2 neighbors in the extended device.
#  Atom 116 has only 2 neighbors in the extended device.
#  Atom 117 has only 2 neighbors in the extended device.
#  Atom 118 has only 2 neighbors in the extended device.
#  Atom 119 has only 2 neighbors in the extended device.
#  Atom 120 has only 2 neighbors in the extended device.
#  Atom 121 has only 2 neighbors in the extended device.
#  Atom 122 has only 2 neighbors in the extended device.
#  Atom 123 has only 2 neighbors in the extended device.
#  Atom 124 has only 2 neighbors in the extended device.
#  Atom 125 has only 2 neighbors in the extended device.
#  Atom 126 has only 2 neighbors in the extended device.
#  Atom 127 has only 2 neighbors in the extended device.
#  Atom 128 has only 2 neighbors in the extended device.
#  Atom 129 has only 2 neighbors in the extended device.
#  Atom 130 has only 2 neighbors in the extended device.
#  Atom 131 has only 2 neighbors in the extended device.
#  Atom 132 has only 2 neighbors in the extended device.
#  Atom 133 has only 2 neighbors in the extended device.
#  Atom 134 has only 2 neighbors in the extended device.
#  Atom 135 has only 2 neighbors in the extended device.
#  Atom 136 has only 2 neighbors in the extended device.
#  Atom 137 has only 2 neighbors in the extended device.
#  Atom 138 has only 2 neighbors in the extended device.
#  Atom 139 has only 2 neighbors in the extended device.
#  Atom 140 has only 2 neighbors in the extended device.
#  Atom 141 has only 2 neighbors in the extended device.
#  Atom 142 has only 2 neighbors in the extended device.
#  Atom 143 has only 2 neighbors in the extended device.
#  Atom 169 has only 1 neighbors in the extended device.
#  Atom 173 has only 1 neighbors in the extended device.
#  Atom 177 has only 1 neighbors in the extended device.
#  Atom 181 has only 1 neighbors in the extended device.
#  Atom 185 has only 1 neighbors in the extended device.
#  Atom 189 has only 1 neighbors in the extended device.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (117, 118), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (115, 116), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (72, 95), setting angle = 0.
#  Warning: No angle found for pair (51, 52), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (57, 58), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (97, 98), setting angle = 0.
#  Warning: No angle found for pair (109, 110), setting angle = 0.
#  Warning: No angle found for pair (61, 62), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (45, 46), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (101, 102), setting angle = 0.
#  Warning: No angle found for pair (53, 54), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (99, 100), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (93, 94), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (63, 64), setting angle = 0.
#  Warning: No angle found for pair (59, 60), setting angle = 0.
#  Warning: No angle found for pair (85, 86), setting angle = 0.
#  Warning: No angle found for pair (49, 50), setting angle = 0.
#  Warning: No angle found for pair (24, 47), setting angle = 0.
#  Warning: No angle found for pair (43, 44), setting angle = 0.
#  Warning: No angle found for pair (105, 106), setting angle = 0.
#  Warning: No angle found for pair (27, 28), setting angle = 0.
#  Warning: No angle found for pair (89, 90), setting angle = 0.
#  Warning: No angle found for pair (41, 42), setting angle = 0.
#  Warning: No angle found for pair (73, 74), setting angle = 0.
#  Warning: No angle found for pair (67, 68), setting angle = 0.
#  Warning: No angle found for pair (81, 82), setting angle = 0.
#  Warning: No angle found for pair (77, 78), setting angle = 0.
#  Warning: No angle found for pair (113, 114), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (103, 104), setting angle = 0.
#  Warning: No angle found for pair (37, 38), setting angle = 0.
#  Warning: No angle found for pair (107, 108), setting angle = 0.
#  Warning: No angle found for pair (83, 84), setting angle = 0.
#  Warning: No angle found for pair (39, 40), setting angle = 0.
#  Warning: No angle found for pair (87, 88), setting angle = 0.
#  Warning: No angle found for pair (31, 32), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (55, 56), setting angle = 0.
#  Warning: No angle found for pair (69, 70), setting angle = 0.
#  Warning: No angle found for pair (65, 66), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (35, 36), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (91, 92), setting angle = 0.
#  Warning: No angle found for pair (25, 26), setting angle = 0.
#  Warning: No angle found for pair (29, 30), setting angle = 0.
#  Warning: No angle found for pair (33, 34), setting angle = 0.
#  Warning: No angle found for pair (79, 80), setting angle = 0.
#  Warning: No angle found for pair (111, 112), setting angle = 0.
#  Warning: No angle found for pair (75, 76), setting angle = 0.
#  Warning: No angle found for pair (96, 119), setting angle = 0.
#  Warning: No angle found for pair (48, 71), setting angle = 0.

# %%
import ase
N_L, N_M, N_R = 1, 4, 1
n,m = 6, 0
bond = 1.42
strain_percentages = np.array([0, 2, 4, 6, 8, 10])

for strain in strain_percentages:
    device = build_device_structure(n=n, m=m, N_L=N_L, N_M=N_M, N_R=N_R, direction='x')
    strained_device = apply_strain(device, strain, axis=0)
    ase.io.write(f'structures/strained_device_{strain}.xyz', strained_device)

# %%
import ase.io
import matplotlib.pyplot as plt
import numpy as np

strains = [0, 10]
offset = 10.0  # vertical offset between CNTs
colors = ['black', 'red']

plt.figure(figsize=(8, 6))
for i, strain in enumerate(strains):
    atoms = ase.io.read(f'structures/strained_device_{strain}.xyz')
    pos = atoms.get_positions()
    pos[:, 2] += i * offset  # shift along z-axis for visualization

    plt.scatter(pos[:, 0], pos[:, 2], label=f"{strain}% strain", s=20, alpha=0.8, c=colors[i])

plt.xlabel("x (Å)")
plt.ylabel("z (Å)")
plt.title("Strained vs Unstrained CNTs")
plt.legend()
plt.axis("equal")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from ase.io import read
from scipy.spatial import cKDTree
import numpy as np

def get_bonds(positions, cutoff=1.7):
    """Return list of bonded atom index pairs based on cutoff distance."""
    tree = cKDTree(positions)
    pairs = tree.query_pairs(cutoff)
    return list(pairs)

fig, ax = plt.subplots(figsize=(10, 6))

# Load both structures
colors = {0: 'gray', 10: 'red'}
for strain in [0, 10]:
    atoms = read(f"structures/strained_device_{strain}.xyz")
    pos = atoms.get_positions()

    # Draw bonds
    bonds = get_bonds(pos)
    for i, j in bonds:
        x = [pos[i, 0], pos[j, 0]]
        y = [pos[i, 1], pos[j, 1]]
        ax.plot(x, y, color=colors[strain], alpha=0.6, linewidth=1.2, zorder=1)

    # Draw atoms
    ax.scatter(pos[:, 0], pos[:, 1], color=colors[strain], edgecolors='k', s=80, label=f"{strain}% strain", zorder=2)

# Optional: highlight atoms (e.g., first 24)
# highlight_indices = list(range(24))
# ax.scatter(pos[highlight_indices, 0], pos[highlight_indices, 1], c='black', s=80, zorder=3)

ax.set_aspect('equal')
ax.axis('off')
ax.legend()
plt.tight_layout()
plt.show()
