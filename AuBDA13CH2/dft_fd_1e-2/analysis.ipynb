# %%
import os

new_path = '/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/dft_fd_1e-2'
os.chdir(new_path)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Eref,Tref = np.load("/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/reference/ET_dft.npy")
E_dmft_ref,T_dmft_ref = np.load("/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/reference/ET_dmft.npy")

# %%
E,T = np.load("./output/lowdin/dyson/beta_100/dft_transmission.npy")
plt.plot(E,T,"x",label='computed dft')
plt.plot(Eref,Tref,".",label='reference dft')
plt.yscale('log')
plt.legend()
plt.xlim(-2,2)
plt.ylim(bottom=1e-5)
# Out:
# (1e-05, 1.3374398490778932)

# %%
Edmft,Tdmft = np.load("/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/dft_fd_1e-2/output/lowdin/dyson/beta_100/gfp_0.0/U_matrix/dmft_transmission.npy")
plt.plot(Edmft,Tdmft,".",label='computed dmft')
plt.plot(E_dmft_ref,T_dmft_ref,".",label='reference dmft')
plt.legend()
plt.xlim(-2,2)
plt.yscale('log')
plt.ylim(bottom=1e-5)
plt.legend()

# %%
Edmft,Tdmft = np.load("/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/dft_fd_1e-2/output/lowdin/dyson/beta_70/nbaths_4/U_matrix/dmft_transmission.npy")
Edmft2,Tdmft2 = np.load("/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/dft_fd_1e-2/output/lowdin/dyson/beta_38.68/nbaths_4/U_matrix/dmft_transmission.npy")
plt.plot(Edmft,Tdmft,label='computed dmft')
plt.plot(Edmft2,Tdmft2,label='computed dmft beta 38.68')
plt.plot(E_dmft_ref,T_dmft_ref,label='reference dmft')
plt.legend()
plt.xlim(-2,2)
plt.yscale('log')
plt.ylim(bottom=1e-5)
plt.legend()

# %%
Edmft,Tdmft = np.load("/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/dft_fd_1e-2/output/lowdin/dyson/beta_70/nbaths_6/U_matrix/dmft_transmission.npy")
plt.plot(Edmft,Tdmft,label='computed dmft')
plt.plot(E_dmft_ref,T_dmft_ref,label='reference dmft')
plt.legend()
plt.xlim(-2,2)
plt.yscale('log')
plt.ylim(bottom=1e-5)
plt.legend()

# %%
Edmft,Tdmft = np.load("/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/dft_fd_1e-2/output/lowdin/dyson/beta_38.68/nbaths_4/U_matrix/dmft_transmission.npy")
plt.plot(Edmft,Tdmft,label='computed dmft')
plt.plot(E_dmft_ref,T_dmft_ref,label='reference dmft')
plt.legend()
plt.xlim(-2,2)
plt.yscale('log')
plt.ylim(bottom=1e-5)
plt.legend()

# %%
E1, Tspinup = np.load("/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/dft_fd_1e-2/output/lowdin/dyson/spin_dmft/beta_38.68/nbaths_4/U_matrix/dmft_transmission_up.npy")
E2, Tspindown = np.load("/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/dft_fd_1e-2/output/lowdin/dyson/spin_dmft/beta_38.68/nbaths_4/U_matrix/dmft_transmission_down.npy")
plt.plot(E1,Tspinup,label='computed dmft spin up')
plt.plot(E2,Tspindown,label='computed dmft spin down')
plt.plot(Edmft2,Tdmft2,label='computed dmft no spin')
plt.legend()
plt.xlim(-2,2)
plt.yscale('log')
plt.ylim(bottom=1e-6)
plt.legend()

# %%
dmft_sigma = np.load("/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/dft_fd_1e-2/output/lowdin/dyson/spin_dmft/beta_38.68/nbaths_4/U_matrix/dmft_sigma.npy")
dmft_sigma.shape
trace_sigma = np.trace(dmft_sigma,axis1=1,axis2=2)
trace_sigma.shape
plt.plot(E1,trace_sigma[0],label='trace sigma up')
plt.plot(E2,trace_sigma[1],label='trace sigma down')
plt.xlim(-2,2)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       3 trace_sigma = np.trace(dmft_sigma,axis1=1,axis2=2)
#       4 trace_sigma.shape
# ----> 5 plt.plot(E1,trace_sigma[0],label='trace sigma up')
#       6 plt.plot(E2,trace_sigma[1],label='trace sigma down')
#       7 plt.xlim(-2,2)
#
# File ~/miniconda3/envs/qtpyt/lib/python3.9/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File ~/miniconda3/envs/qtpyt/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File ~/miniconda3/envs/qtpyt/lib/python3.9/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/miniconda3/envs/qtpyt/lib/python3.9/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (3,) and (401,)
