# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
H, S = np.load("hs_cc_k.npy")
print(H.shape, S.shape)
# Out:
# (1, 648, 648) (1, 648, 648)

# %%
plt.imshow(H[0])
plt.colorbar()
plt.title("H")
plt.show()
plt.imshow(S[0])
plt.colorbar()
plt.title("S")
plt.show()

# %%
print("H", np.round(H[0],3))
# Out:
# H [[-1.4228e+01  0.0000e+00 -1.4700e+00 ...  4.0000e-01 -7.4000e-02
#   -5.9300e-01]
#  [ 0.0000e+00 -7.8680e+00 -0.0000e+00 ...  0.0000e+00  0.0000e+00
#   -0.0000e+00]
#  [-1.4700e+00 -0.0000e+00 -2.8050e+00 ...  1.2000e-02 -3.0700e-01
#   -5.7000e-02]
#  ...
#  [ 4.0000e-01  0.0000e+00  1.2000e-02 ...  2.4228e+01  1.0200e-01
#    4.8800e-01]
#  [-7.4000e-02  0.0000e+00 -3.0700e-01 ...  1.0200e-01  2.4392e+01
#   -1.9900e-01]
#  [-5.9300e-01 -0.0000e+00 -5.7000e-02 ...  4.8800e-01 -1.9900e-01
#    1.7989e+01]]

# %%
int(0.2*np.pi/(0.246))
# Out:
# 2

# %%
int(np.pi/(0.246))
# Out:
# 12

# %%
0.246*6/np.pi
# Out:
# 0.469825392007275
