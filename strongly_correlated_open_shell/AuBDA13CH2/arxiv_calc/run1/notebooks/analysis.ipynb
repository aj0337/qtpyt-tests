# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# new_path = '/capstor/scratch/cscs/ajayaraj/qtpyt-tests/AuBDA13CH2/run1'
# os.chdir(new_path)

# %%
E_ref, T_ref = np.load("../../reference/ET_dft.npy")
E, T_dft = np.load("../output/lowdin/dft_transmission.npy")
plt.plot(E_ref,T_ref,label="Reference")
plt.plot(E,T_dft,label='DFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-5)
# Out:
# (1e-05, 2.1593827496001117)

# %%
_,T = np.load("./output/lowdin/dmft/no_spin/dmft_transmission.npy")
plt.plot(E,T,label='DMFT no spin')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-5)
# Out:
# (1e-05, 1.529435741049291)

# %%
_,T_spin_up = np.load("./output/lowdin/dmft/spin/dmft_transmission_up.npy")
_,T_spin_down = np.load("./output/lowdin/dmft/spin/dmft_transmission_down.npy")
plt.plot(E,T_spin_up,label='DMFT spin up')
plt.plot(E,T_spin_down,label='DMFT spin down')
plt.plot(E,T_dft,label='DFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 _,T_spin_up = np.load("./output/lowdin/dmft/spin/dmft_transmission_up.npy")
#       2 _,T_spin_down = np.load("./output/lowdin/dmft/spin/dmft_transmission_down.npy")
#       3 plt.plot(E,T_spin_up,label='DMFT spin up')
#
# File ~/miniconda3/envs/qtpyt/lib/python3.9/site-packages/numpy/lib/npyio.py:417, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415     own_fid = False
#     416 else:
# --> 417     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418     own_fid = True
#     420 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/lowdin/dmft/spin/dmft_transmission_up.npy'

# %%
_,T1 = np.load("./output/lowdin/ed/ed_transmission.npy")
_,T2 = np.load("./output/lowdin/ed/ed_transmission_test.npy")
plt.plot(E,T1,label='ED1')
plt.plot(E,T2,label='ED2')
plt.plot(E,T_dft,label='dft')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-5)
# Out:
# (1e-05, 1.653766459026203)
