# %%
import numpy as np
import matplotlib.pyplot as plt
new_path = '/capstor/scratch/cscs/ajayaraj/qtpyt-tests/pentadienyl'
os.chdir(new_path)

# %% [markdown]
# ### Spin unpolarized tests

# %%
E_ref, T_ref  = np.load("../reference/ET_dmft.npy")

# %%
E,T_dft = np.load("../output/lowdin/dft_transmission.npy")
plt.plot(E,T_dft,label='DFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3125178451825836)

# %%
E,T = np.load("../output/lowdin/beta_1000/dmft/no_spin/nbaths_4/fix_mu_0/eta_1e-3/dmft_transmission.npy")
E2,T2 = np.load("../output/lowdin/beta_1000/dmft/no_spin/nbaths_4/fix_mu_0/eta_3e-2/dmft_transmission.npy")
# plt.plot(E,T,label='DMFT no spin, eta = 1e-3')
plt.plot(E2,T2,label='DMFT no spin, eta = 3e-2')
plt.plot(E_ref,T_ref,label='DMFT reference')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.0190449558622348)

# %% [markdown]
# ### Spin polarized tests

# %%
Eref,Tref = np.load("../reference/ET_dft.npy")
_, Tref_up = np.load("../reference/ET_dmft_up.npy")
_, Tref_down = np.load("../reference/ET_dmft_dw.npy")

# %%
E,T_spin_up = np.load("../output/lowdin/beta_1000/dmft/alternating_sign/spin/dmft_transmission_up.npy")
_,T_spin_down = np.load("../output/lowdin/beta_1000/dmft/alternating_sign/spin/dmft_transmission_dw.npy")

plt.plot(Eref,Tref_up,label='DMFT spin up ref',color='red',linestyle='--')
plt.plot(Eref,Tref_down,label='DMFT spin down ref',color='blue',linestyle='--')

plt.plot(E,T_spin_up,label='DMFT spin up')
plt.plot(E,T_spin_down,label='DMFT spin down')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.764078815151623)

# %%
E, T_dmft = np.load("../output/lowdin/beta_38.68/dmft/no_spin/dmft_transmission.npy")
E2, T2_dmft = np.load("../output/lowdin/beta_1000/dmft/no_spin/nbaths_6/dmft_transmission.npy")

# %%
# _,T_spin_up = np.load("../output/lowdin/beta_1000/dmft/spin/dmft_transmission_up.npy")
# _,T_spin_down = np.load("../output/lowdin/beta_1000/dmft/spin/dmft_transmission_dw.npy")
# plt.plot(E,T_spin_up,label='DMFT spin up',color='red')
# plt.plot(E,T_spin_down,label='DMFT spin down',color='blue')
# plt.plot(E,T_dft,label='DFT',color='black')
plt.plot(E,T_dmft,label='DMFT nbath = 4',color='black')
plt.plot(E2,T2_dmft,label='DMFT nbath = 6',color='red')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylabel('Transmission')
plt.xlabel('Energy (eV)')
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3114847764805755)

# %%
E,T_spin_up = np.load("./output/lowdin/beta_1000/dmft/spin/field_0.005/adjust_mu_False/dmft_transmission_up.npy")
_,T_spin_down = np.load("./output/lowdin/beta_1000/dmft/spin/field_0.005/adjust_mu_False/dmft_transmission_dw.npy")

plt.plot(Eref,Tref_up,label='DMFT spin up ref',color='red',linestyle='--')
plt.plot(Eref,Tref_down,label='DMFT spin down ref',color='blue',linestyle='--')

plt.plot(E,T_spin_up,label='DMFT spin up')
plt.plot(E,T_spin_down,label='DMFT spin down')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.9091406920652005)

# %%
E,T_spin_up = np.load("../output/lowdin/beta_1000/dmft/spin/field_0.5/adjust_mu_False/dmft_transmission_up.npy")
_,T_spin_down = np.load("../output/lowdin/beta_1000/dmft/spin/field_0.5/adjust_mu_False/dmft_transmission_dw.npy")

plt.plot(Eref,Tref_up,label='DMFT spin up ref',color='red',linestyle='--')
plt.plot(Eref,Tref_down,label='DMFT spin down ref',color='blue',linestyle='--')

plt.plot(E,T_spin_up,label='DMFT spin up')
plt.plot(E,T_spin_down,label='DMFT spin down')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.6896669366555332)

# %% [markdown]
# ### Ferretti correction tests

# %%
E,T_dft = np.load("./output/lowdin/ferretti/dft_transmission_non_btm_no_correction.npy")
plt.plot(E,T_dft,label='DFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3125199653653439)

# %%
E,T_dft = np.load("./output/lowdin/ferretti/dft_transmission_non_btm_ferretti_correction.npy")
plt.plot(E,T_dft,label='DFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3125199653653439)

# %%
E,T_dft = np.load("./output/lowdin/ferretti/dft_transmission_btm_no_correction.npy")
plt.plot(E,T_dft,label='DFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 E,T_dft = np.load("./output/lowdin/ferretti/dft_transmission_btm_no_correction.npy")
#       2 plt.plot(E,T_dft,label='DFT')
#       3 plt.yscale('log')
#
# File ~/miniconda3/envs/guido-edpyt-qtpyt/lib/python3.9/site-packages/numpy/lib/npyio.py:417, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415     own_fid = False
#     416 else:
# --> 417     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418     own_fid = True
#     420 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/lowdin/ferretti/dft_transmission_btm_no_correction.npy'

# %%
E,T_dmft = np.load("../output/lowdin/ferretti/dmft_transmission_non_btm_no_correction.npy")
E_f,T_dmft_f = np.load("../output/lowdin/ferretti/dmft_transmission_non_btm_ferretti_correction.npy")
plt.plot(E,T_dmft,label='DMFT no correction')
plt.plot(E_f,T_dmft_f,label='DMFT ferretti correction')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3114854359753625)

# %%
E_dmft,T_dmft = np.load("./output/lowdin/ferretti/dmft_transmission_non_btm_ferretti_correction.npy")
plt.plot(E_dmft,T_dmft,label='DMFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.246756062350951)

# %%
E,T_dmft = np.load("./output/lowdin/ferretti/dmft_transmission_btm_no_correction.npy")
plt.plot(E,T_dmft,label='DMFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3114847764805755)

# %%
E,T_dmft = np.load("../output/lowdin/ferretti/dmft_transmission_btm_ferretti_correction.npy")
plt.plot(E,T_dmft,label='DMFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3362176898158813)

# %%
index_active_region = np.load("./output/lowdin/index_active_region.npy")
de = 0.01
energies = np.arange(-15, 15 + de / 2.0, de).round(7)

index_C_2pz = np.array([1147, 1160, 1183, 1196, 1219])
index_N_2pz = np.array([1119,1232])
index_molecule = np.arange(1116, 1235)

n_orbitals = 2368
all_indices = np.arange(n_orbitals)
index_Au = np.setdiff1d(all_indices, index_molecule)

# %%
pdos = np.load("./output/lowdin/pdos_spectral.npy")

# Sum PDOS over the active region
pdos_active = pdos[:, index_active_region]  # shape (601, 7)
pdos_active_sum = np.sum(pdos_active, axis=1)  # shape (601,)


pdos_N_2pz = pdos[:, index_N_2pz]
pdos_N_2pz_sum = np.sum(np.abs(pdos_N_2pz), axis=1)

pdos_C_2pz = pdos[:, index_C_2pz]
pdos_C_2pz_sum = np.sum(np.abs(pdos_C_2pz), axis=1)

pdos_molecule = pdos[:, index_molecule]
pdos_molecule_sum = np.sum(np.abs(pdos_molecule), axis=1)

pdos_Au = pdos[:, index_Au]
pdos_Au_sum = np.sum(np.abs(pdos_Au), axis=1)

dos = np.sum(np.abs(pdos), axis=1)

plt.figure(figsize=(6, 4))
plt.plot(energies, np.abs(pdos_N_2pz_sum),label='N_2pz')
plt.plot(energies, np.abs(pdos_C_2pz_sum),label='C_2pz')
plt.plot(energies, np.abs(pdos_molecule_sum),label='Molecule')
# plt.plot(energies, np.abs(pdos_Au_sum),label='Au')
# plt.plot(energies, np.abs(dos),label='Total DOS')
plt.legend()
plt.xlabel("Energy (eV)")
plt.ylabel("PDOS (N_2pz region)")
plt.title("Projected DOS (Summed over N_2pz Region)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
pdos = np.load("./output/lowdin/pdos_dyson.npy")

# Sum PDOS over the active region
pdos_active = pdos[:, index_active_region]  # shape (601, 7)
pdos_active_sum = np.sum(pdos_active, axis=1)  # shape (601,)


pdos_N_2pz = pdos[:, index_N_2pz]
pdos_N_2pz_sum = np.sum((pdos_N_2pz), axis=1)

pdos_C_2pz = pdos[:, index_C_2pz]
pdos_C_2pz_sum = np.sum((pdos_C_2pz), axis=1)

pdos_molecule = pdos[:, index_molecule]
pdos_molecule_sum = np.sum((pdos_molecule), axis=1)

pdos_Au = pdos[:, index_Au]
pdos_Au_sum = np.sum((pdos_Au), axis=1)

dos = np.sum((pdos), axis=1)

plt.figure(figsize=(6, 4))
plt.plot(energies, (pdos_N_2pz_sum),label='N_2pz')
plt.plot(energies, (pdos_C_2pz_sum),label='C_2pz')
plt.plot(energies, (pdos_molecule_sum),label='Molecule')
# plt.plot(energies, (pdos_Au_sum),label='Au')
# plt.plot(energies, (dos),label='Total DOS')
plt.legend()
plt.xlabel("Energy (eV)")
plt.ylabel("PDOS ")
plt.grid(True)
plt.xlim(-3,3)
plt.ylim(0,10)
# plt.yscale('log')
plt.tight_layout()
plt.show()

# %%
pdos = np.load("./output/lowdin/pdos_dyson_no_leads_se.npy")

# Sum PDOS over the active region
pdos_active = pdos[:, index_active_region]  # shape (601, 7)
pdos_active_sum = np.sum(pdos_active, axis=1)  # shape (601,)


pdos_N_2pz = pdos[:, index_N_2pz]
pdos_N_2pz_sum = np.sum((pdos_N_2pz), axis=1)

pdos_C_2pz = pdos[:, index_C_2pz]
pdos_C_2pz_sum = np.sum((pdos_C_2pz), axis=1)

pdos_molecule = pdos[:, index_molecule]
pdos_molecule_sum = np.sum((pdos_molecule), axis=1)

pdos_Au = pdos[:, index_Au]
pdos_Au_sum = np.sum((pdos_Au), axis=1)

dos = np.sum((pdos), axis=1)

plt.figure(figsize=(6, 4))
plt.plot(energies, (pdos_N_2pz_sum),label='N_2pz')
plt.plot(energies, (pdos_C_2pz_sum),label='C_2pz')
plt.plot(energies, (pdos_molecule_sum),label='Molecule')
# plt.plot(energies, (pdos_Au_sum),label='Au')
# plt.plot(energies, (dos),label='Total DOS')
plt.legend()
plt.xlabel("Energy (eV)")
plt.ylabel("PDOS ")
plt.grid(True)
plt.xlim(-7,5)
# plt.yscale('log')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exact diagonalization

# %%
sigma_ed = np.load("./output/lowdin/beta_1000/ed/sigma_ed.npy")
trace_sigma_ed = np.trace(sigma_ed,axis1=1, axis2=2)
energies = np.arange(-20, 20.1, 0.1)
plt.plot(energies,trace_sigma_ed.real,label='Real part')
plt.plot(energies,trace_sigma_ed.imag,label='Imaginary part')
plt.legend()
plt.xlim(-20,-18)
plt.ylim(-50,50)
plt.xlabel("Energy (eV)")
plt.ylabel("Trace of Sigma_ed")
plt.title("Trace of Sigma_ed")
plt.grid(True)
plt.show()

# %%
E,T = np.load("./output/lowdin/beta_1000/ed/transmission_test.npy")
Eref, Tref = np.load("./reference/ET_ed.npy")
E_dmft,T_dmft = np.load("./output/lowdin/ferretti/dmft_transmission_btm_no_correction.npy")
plt.plot(E_dmft,T_dmft,label='DMFT')
plt.plot(Eref,Tref,label='ED transmission ref',color='black',linestyle='--')
plt.plot(E,T,label='ED transmission computed',color='red')
plt.legend()
plt.xlabel("Energy (eV)")
plt.ylabel("Transmission")
plt.yscale('log')
plt.xlim(-2.5,2.5)
# Out:
# (-2.5, 2.5)

# %%
E,T = np.load("./output/lowdin/beta_1000/ed/transmission_test.npy")
Eref, Tref = np.load("./reference/ET_ed.npy")
plt.plot(Eref,Tref,label='ED transmission ref',color='black',linestyle='--')
plt.plot(E,T,label='ED transmission computed',color='red')
plt.legend()
plt.xlabel("Energy (eV)")
plt.ylabel("Transmission")
plt.yscale('log')
plt.xlim(-2.5,2.5)
# Out:
# (-2.5, 2.5)
