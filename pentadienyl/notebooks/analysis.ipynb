# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# new_path = '/capstor/scratch/cscs/ajayaraj/qtpyt-tests/pentadienyl'
# os.chdir(new_path)

# %%
E,T_dft = np.load("../output/lowdin/dft_transmission.npy")
plt.plot(E,T_dft,label='DFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 E,T_dft = np.load("../output/lowdin/dft_transmission.npy")
#       2 plt.plot(E,T_dft,label='DFT')
#       3 plt.yscale('log')
#
# File ~/miniconda3/envs/qtpyt/lib/python3.9/site-packages/numpy/lib/npyio.py:417, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415     own_fid = False
#     416 else:
# --> 417     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418     own_fid = True
#     420 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output/lowdin/dft_transmission.npy'

# %%
_,T = np.load("../output/lowdin/dmft/no_spin/dmft_transmission.npy")
plt.plot(E,T,label='DMFT no spin')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 _,T = np.load("../output/lowdin/dmft/no_spin/dmft_transmission.npy")
#       2 plt.plot(E,T,label='DMFT no spin')
#       3 plt.yscale('log')
#
# File ~/miniconda3/envs/guido-edpyt-qtpyt/lib/python3.9/site-packages/numpy/lib/npyio.py:417, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415     own_fid = False
#     416 else:
# --> 417     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418     own_fid = True
#     420 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output/lowdin/dmft/no_spin/dmft_transmission.npy'

# %%
Eref,Tref = np.load("./reference/ET_dft.npy")
_, Tref_up = np.load("./reference/ET_dmft_up.npy")
_, Tref_down = np.load("./reference/ET_dmft_dw.npy")

# %%
_,T_spin_up = np.load("../output/lowdin/beta_1000/dmft/spin/dmft_transmission_up.npy")
_,T_spin_down = np.load("../output/lowdin/beta_1000/dmft/spin/dmft_transmission_dw.npy")
plt.plot(E,T_spin_up,label='DMFT spin up',color='red')
plt.plot(E,T_spin_down,label='DMFT spin down',color='blue')
plt.plot(E,T_dft,label='DFT',color='black')
plt.plot(E,T_dmft,label='DMFT',color='green')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylabel('Transmission')
plt.xlabel('Energy (eV)')
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.6172328053603608)

# %%
E,T_spin_up = np.load("./output/lowdin/beta_1000/dmft/spin/field_0.005/adjust_mu_False/dmft_transmission_up.npy")
_,T_spin_down = np.load("./output/lowdin/beta_1000/dmft/spin/field_0.005/adjust_mu_False/dmft_transmission_dw.npy")

plt.plot(Eref,Tref_up,label='DMFT spin up ref',color='red',linestyle='--')
plt.plot(Eref,Tref_down,label='DMFT spin down ref',color='blue',linestyle='--')

plt.plot(E,T_spin_up,label='DMFT spin up')
plt.plot(E,T_spin_down,label='DMFT spin down')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.9091406920652005)

# %%
E,T_dft = np.load("./output/lowdin/ferretti/dft_transmission_non_btm_no_correction.npy")
plt.plot(E,T_dft,label='DFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3125199653653439)

# %%
E,T_dft = np.load("./output/lowdin/ferretti/dft_transmission_non_btm_ferretti_correction.npy")
plt.plot(E,T_dft,label='DFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3125199653653439)

# %%
E,T_dft = np.load("./output/lowdin/ferretti/dft_transmission_btm_no_correction.npy")
plt.plot(E,T_dft,label='DFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 E,T_dft = np.load("./output/lowdin/ferretti/dft_transmission_btm_no_correction.npy")
#       2 plt.plot(E,T_dft,label='DFT')
#       3 plt.yscale('log')
#
# File ~/miniconda3/envs/guido-edpyt-qtpyt/lib/python3.9/site-packages/numpy/lib/npyio.py:417, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415     own_fid = False
#     416 else:
# --> 417     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418     own_fid = True
#     420 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './output/lowdin/ferretti/dft_transmission_btm_no_correction.npy'

# %%
E,T_dmft = np.load("../output/lowdin/ferretti/dmft_transmission_non_btm_no_correction.npy")
E_f,T_dmft_f = np.load("../output/lowdin/ferretti/dmft_transmission_non_btm_ferretti_correction.npy")
plt.plot(E,T_dmft,label='DMFT no correction')
plt.plot(E_f,T_dmft_f,label='DMFT ferretti correction')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3114854359753625)

# %%
E,T_dmft = np.load("../output/lowdin/ferretti/dmft_transmission_non_btm_ferretti_correction.npy")
plt.plot(E,T_dmft,label='DMFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3114854311475324)

# %%
E,T_dmft = np.load("../output/lowdin/ferretti/dmft_transmission_btm_no_correction.npy")
plt.plot(E,T_dmft,label='DMFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3114847764805755)

# %%
E,T_dmft = np.load("../output/lowdin/ferretti/dmft_transmission_btm_ferretti_correction.npy")
plt.plot(E,T_dmft,label='DMFT')
plt.yscale('log')
plt.legend()
plt.xlim(-2.5,2.5)
plt.ylim(bottom=1e-4)
# Out:
# (0.0001, 1.3362176898158813)
